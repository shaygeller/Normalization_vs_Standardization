# %% [markdown]
# # Normalization vs Standardization  - Quantitative analysis

# %% [markdown]
# This notebook containes the code to extract tables and info used in my Medium article - TODO:add link

# %% [markdown]
# # Let's read the data

# %%
import os
import sys
import sys
sys.path.append("../..")
from src.data.bank_additional import BandAdditionalParser
from src.data.income_evaluation import IncomeEvaluationParser
from src.data.skyserver import SkyserverParser
from src.data.sonar import SonarParser
from src.data.weather_aus import WeatherAUSParser



avaliable_restul_files = {
    "sonar_results.csv": SonarParser,
    "Skyserver_results.csv": SkyserverParser,
    "income_evaluation_results.csv": IncomeEvaluationParser,
    "bank-additional_results.csv": BandAdditionalParser,
    "weatherAUS_results.csv": WeatherAUSParser
}


# Pick one of the keys name in the above dictionarys and paste it in results_file variable. Then run all the cells
results_file = "sonar_results.csv"

# %%
# Pick the wanted parser and run the cells
parser = avaliable_restul_files[results_file]()
X,y = parser.X, parser.y
X.head(5)
# Out:
# ############################## Start Dataset - sonar Stats ##############################
# Dataset shape: (208, 61)
# Counts for each class:
# M    111
# R     97
# Name: 60, dtype: int64
# Sample of first 5 rows:
#         0       1       2       3       4       5       6       7       8  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#         9 ...      51      52      53      54      55      56      57      58  \
# 0  0.2111 ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  0.0090
# 1  0.2872 ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049  0.0052
# 2  0.6194 ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164  0.0095
# 3  0.1264 ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044  0.0040
# 4  0.4459 ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048  0.0107
#
#        59  60
# 0  0.0032   R
# 1  0.0044   R
# 2  0.0078   R
# 3  0.0117   R
# 4  0.0094   R
#
# [5 rows x 61 columns]
# ############################## End Dataset Stats ##############################
#         0       1       2       3       4       5       6       7       8  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#         9   ...        50      51      52      53      54      55      56  \
# 0  0.2111   ...    0.0232  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180
# 1  0.2872   ...    0.0125  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140
# 2  0.6194   ...    0.0033  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316
# 3  0.1264   ...    0.0241  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050
# 4  0.4459   ...    0.0156  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072
#
#        57      58      59
# 0  0.0084  0.0090  0.0032
# 1  0.0049  0.0052  0.0044
# 2  0.0164  0.0095  0.0078
# 3  0.0044  0.0040  0.0117
# 4  0.0048  0.0107  0.0094
#
# [5 rows x 60 columns]

# %%
print("Data shape: ", X.shape)
print(y.value_counts())
# Out:
# Data shape:  (208, 60)
# M    111
# R     97
# Name: 60, dtype: int64

# %% [markdown]
# ### Let's read the results file

# %%
import os
import pandas as pd


results_df = pd.read_csv(os.path.join("..", "..", "data", "processed", results_file)).dropna().round(3)
results_df
# Out:
#     Dataset                       Classifier_Name  CV_mean  CV_std  Test_score
# 0     sonar                                   _LR    0.754   0.114       0.714
# 1     sonar                     StandardScaler_LR    0.742   0.105       0.833
# 2     sonar                       MinMaxScaler_LR    0.778   0.121       0.762
# 3     sonar                       MaxAbsScaler_LR    0.778   0.121       0.762
# 4     sonar                       RobustScaler_LR    0.735   0.077       0.810
# 5     sonar         QuantileTransformer-Normal_LR    0.718   0.135       0.810
# 6     sonar        QuantileTransformer-Uniform_LR    0.808   0.117       0.786
# 7     sonar       PowerTransformer-Yeo-Johnson_LR    0.760   0.089       0.833
# 8     sonar                         Normalizer_LR    0.699   0.097       0.690
# 10    sonar                               _LR-PCA    0.699   0.102       0.619
# 11    sonar                 StandardScaler_LR-PCA    0.753   0.147       0.738
# 12    sonar                   MinMaxScaler_LR-PCA    0.753   0.145       0.714
# 13    sonar                   MaxAbsScaler_LR-PCA    0.759   0.142       0.714
# 14    sonar                   RobustScaler_LR-PCA    0.734   0.131       0.738
# 15    sonar     QuantileTransformer-Normal_LR-PCA    0.741   0.155       0.714
# 16    sonar    QuantileTransformer-Uniform_LR-PCA    0.789   0.117       0.738
# 17    sonar   PowerTransformer-Yeo-Johnson_LR-PCA    0.782   0.117       0.714
# 18    sonar                     Normalizer_LR-PCA    0.631   0.069       0.571
# 20    sonar                                  _LDA    0.699   0.132       0.833
# 21    sonar                    StandardScaler_LDA    0.699   0.132       0.833
# 22    sonar                      MinMaxScaler_LDA    0.699   0.132       0.833
# 23    sonar                      MaxAbsScaler_LDA    0.699   0.132       0.833
# 24    sonar                      RobustScaler_LDA    0.699   0.132       0.833
# 25    sonar        QuantileTransformer-Normal_LDA    0.694   0.156       0.738
# 26    sonar       QuantileTransformer-Uniform_LDA    0.742   0.098       0.786
# 27    sonar      PowerTransformer-Yeo-Johnson_LDA    0.747   0.096       0.786
# 28    sonar                        Normalizer_LDA    0.692   0.115       0.833
# 30    sonar                              _LDA-PCA    0.704   0.093       0.643
# 31    sonar                StandardScaler_LDA-PCA    0.741   0.143       0.714
# 32    sonar                  MinMaxScaler_LDA-PCA    0.753   0.145       0.714
# ..      ...                                   ...      ...     ...         ...
# 126   sonar        QuantileTransformer-Uniform_RF    0.717   0.135       0.810
# 127   sonar       PowerTransformer-Yeo-Johnson_RF    0.710   0.126       0.810
# 128   sonar                         Normalizer_RF    0.723   0.117       0.762
# 130   sonar                               _RF-PCA    0.711   0.096       0.786
# 131   sonar                 StandardScaler_RF-PCA    0.675   0.120       0.762
# 132   sonar                   MinMaxScaler_RF-PCA    0.728   0.118       0.738
# 133   sonar                   MaxAbsScaler_RF-PCA    0.729   0.124       0.810
# 134   sonar                   RobustScaler_RF-PCA    0.703   0.149       0.786
# 135   sonar     QuantileTransformer-Normal_RF-PCA    0.766   0.105       0.833
# 136   sonar    QuantileTransformer-Uniform_RF-PCA    0.668   0.137       0.810
# 137   sonar   PowerTransformer-Yeo-Johnson_RF-PCA    0.710   0.128       0.762
# 138   sonar                     Normalizer_RF-PCA    0.643   0.086       0.643
# 140   sonar                                  _MLP    0.778   0.125       0.833
# 141   sonar                    StandardScaler_MLP    0.820   0.084       0.881
# 142   sonar                      MinMaxScaler_MLP    0.767   0.143       0.810
# 143   sonar                      MaxAbsScaler_MLP    0.767   0.143       0.810
# 144   sonar                      RobustScaler_MLP    0.808   0.088       0.881
# 145   sonar        QuantileTransformer-Normal_MLP    0.808   0.117       0.833
# 146   sonar       QuantileTransformer-Uniform_MLP    0.808   0.106       0.833
# 147   sonar      PowerTransformer-Yeo-Johnson_MLP    0.839   0.111       0.881
# 148   sonar                        Normalizer_MLP    0.724   0.132       0.762
# 150   sonar                              _MLP-PCA    0.705   0.085       0.738
# 151   sonar                StandardScaler_MLP-PCA    0.777   0.091       0.762
# 152   sonar                  MinMaxScaler_MLP-PCA    0.747   0.110       0.786
# 153   sonar                  MaxAbsScaler_MLP-PCA    0.741   0.108       0.786
# 154   sonar                  RobustScaler_MLP-PCA    0.771   0.089       0.810
# 155   sonar    QuantileTransformer-Normal_MLP-PCA    0.729   0.120       0.810
# 156   sonar   QuantileTransformer-Uniform_MLP-PCA    0.776   0.104       0.786
# 157   sonar  PowerTransformer-Yeo-Johnson_MLP-PCA    0.770   0.123       0.786
# 158   sonar                    Normalizer_MLP-PCA    0.619   0.097       0.571
#
# [144 rows x 5 columns]

# %% [markdown]
# <a id="Out-of-the-box_classifier"></a>
# # 1. Out-of-the-box classifiers

# %%
import operator
results_df.loc[operator.and_(results_df["Classifier_Name"].str.startswith("_"), ~results_df["Classifier_Name"].str.endswith("PCA"))].dropna()
# Out:
#     Dataset Classifier_Name  CV_mean  CV_std  Test_score
# 0     sonar             _LR    0.754   0.114       0.714
# 20    sonar            _LDA    0.699   0.132       0.833
# 40    sonar            _KNN    0.753   0.081       0.762
# 60    sonar           _CART    0.735   0.067       0.810
# 80    sonar             _NB    0.657   0.131       0.690
# 100   sonar            _SVM    0.608   0.116       0.738
# 120   sonar             _RF    0.710   0.126       0.810
# 140   sonar            _MLP    0.778   0.125       0.833

# %% [markdown]
# <a id="Classifiers_Scaling"></a>
# # 2. Classifiers+Scaling

# %%
import operator
import numpy as np


temp = results_df.loc[~results_df["Classifier_Name"].str.endswith("PCA")].dropna()
temp["model"] = results_df["Classifier_Name"].apply(lambda sen: sen.split("_")[1])
temp["scaler"] = results_df["Classifier_Name"].apply(lambda sen: sen.split("_")[0])

def df_style(val):
    return 'font-weight: 800'
    

pivot_t = pd.pivot_table(temp, values='CV_mean', index=["scaler"], columns=['model'], aggfunc=np.sum)
pivot_t_bold = pivot_t.style.applymap(df_style,
                      subset=pd.IndexSlice[pivot_t["CART"].idxmax(),"CART"])
for col in list(pivot_t):
    pivot_t_bold = pivot_t_bold.applymap(df_style,
                      subset=pd.IndexSlice[pivot_t[col].idxmax(),col])
pivot_t_bold
# Out:
# <style  type="text/css" >
#     #T_fc7413cc_552c_11e9_9359_d0c5d31508a0row2_col1 {
#             font-weight:  800;
#         }    #T_fc7413cc_552c_11e9_9359_d0c5d31508a0row3_col6 {
#             font-weight:  800;
#         }    #T_fc7413cc_552c_11e9_9359_d0c5d31508a0row4_col2 {
#             font-weight:  800;
#         }    #T_fc7413cc_552c_11e9_9359_d0c5d31508a0row4_col4 {
#             font-weight:  800;
#         }    #T_fc7413cc_552c_11e9_9359_d0c5d31508a0row4_col5 {
#             font-weight:  800;
#         }    #T_fc7413cc_552c_11e9_9359_d0c5d31508a0row6_col0 {
#             font-weight:  800;
#             font-weight:  800;
#         }    #T_fc7413cc_552c_11e9_9359_d0c5d31508a0row6_col3 {
#             font-weight:  800;
#         }    #T_fc7413cc_552c_11e9_9359_d0c5d31508a0row8_col7 {
#             font-weight:  800;
#         }</style>
# <table id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0" >
# <thead>    <tr>
#         <th class="index_name level0" >model</th>
#         <th class="col_heading level0 col0" >CART</th>
#         <th class="col_heading level0 col1" >KNN</th>
#         <th class="col_heading level0 col2" >LDA</th>
#         <th class="col_heading level0 col3" >LR</th>
#         <th class="col_heading level0 col4" >MLP</th>
#         <th class="col_heading level0 col5" >NB</th>
#         <th class="col_heading level0 col6" >RF</th>
#         <th class="col_heading level0 col7" >SVM</th>
#     </tr>    <tr>
#         <th class="index_name level0" >scaler</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0level0_row0" class="row_heading level0 row0" ></th>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row0_col0" class="data row0 col0" >0.735</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row0_col1" class="data row0 col1" >0.753</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row0_col2" class="data row0 col2" >0.699</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row0_col3" class="data row0 col3" >0.754</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row0_col4" class="data row0 col4" >0.778</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row0_col5" class="data row0 col5" >0.657</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row0_col6" class="data row0 col6" >0.71</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row0_col7" class="data row0 col7" >0.608</td>
#     </tr>    <tr>
#         <th id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0level0_row1" class="row_heading level0 row1" >MaxAbsScaler</th>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row1_col0" class="data row1 col0" >0.735</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row1_col1" class="data row1 col1" >0.808</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row1_col2" class="data row1 col2" >0.699</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row1_col3" class="data row1 col3" >0.778</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row1_col4" class="data row1 col4" >0.767</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row1_col5" class="data row1 col5" >0.657</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row1_col6" class="data row1 col6" >0.71</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row1_col7" class="data row1 col7" >0.705</td>
#     </tr>    <tr>
#         <th id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0level0_row2" class="row_heading level0 row2" >MinMaxScaler</th>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row2_col0" class="data row2 col0" >0.735</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row2_col1" class="data row2 col1" >0.813</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row2_col2" class="data row2 col2" >0.699</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row2_col3" class="data row2 col3" >0.778</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row2_col4" class="data row2 col4" >0.767</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row2_col5" class="data row2 col5" >0.657</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row2_col6" class="data row2 col6" >0.71</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row2_col7" class="data row2 col7" >0.711</td>
#     </tr>    <tr>
#         <th id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0level0_row3" class="row_heading level0 row3" >Normalizer</th>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row3_col0" class="data row3 col0" >0.716</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row3_col1" class="data row3 col1" >0.765</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row3_col2" class="data row3 col2" >0.692</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row3_col3" class="data row3 col3" >0.699</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row3_col4" class="data row3 col4" >0.724</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row3_col5" class="data row3 col5" >0.662</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row3_col6" class="data row3 col6" >0.723</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row3_col7" class="data row3 col7" >0.524</td>
#     </tr>    <tr>
#         <th id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0level0_row4" class="row_heading level0 row4" >PowerTransformer-Yeo-Johnson</th>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row4_col0" class="data row4 col0" >0.729</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row4_col1" class="data row4 col1" >0.813</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row4_col2" class="data row4 col2" >0.747</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row4_col3" class="data row4 col3" >0.76</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row4_col4" class="data row4 col4" >0.839</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row4_col5" class="data row4 col5" >0.752</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row4_col6" class="data row4 col6" >0.71</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row4_col7" class="data row4 col7" >0.814</td>
#     </tr>    <tr>
#         <th id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0level0_row5" class="row_heading level0 row5" >QuantileTransformer-Normal</th>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row5_col0" class="data row5 col0" >0.735</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row5_col1" class="data row5 col1" >0.783</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row5_col2" class="data row5 col2" >0.694</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row5_col3" class="data row5 col3" >0.718</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row5_col4" class="data row5 col4" >0.808</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row5_col5" class="data row5 col5" >0.752</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row5_col6" class="data row5 col6" >0.717</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row5_col7" class="data row5 col7" >0.832</td>
#     </tr>    <tr>
#         <th id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0level0_row6" class="row_heading level0 row6" >QuantileTransformer-Uniform</th>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row6_col0" class="data row6 col0" >0.74</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row6_col1" class="data row6 col1" >0.789</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row6_col2" class="data row6 col2" >0.742</td>
#         <td id="T_fc7413cc_552c_11e9_9359_d0c5d31508a0row6_col3" class="data row6 col3" >0.808</td>
#         <

# %%
# Print table for the Medium article

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 100000)
pd.options.display.max_rows
pd.set_option('display.max_colwidth', -1)

dict2 = {'StandardScaler': "StandardScaler",
'MinMaxScaler':"MinMaxScaler",
'MaxAbsScaler':"MaxAbsScaler",
'RobustScaler':"RobustScaler",
'QuantileTransformer-Normal':"QuantileTransformer(output_distribution='normal')",
'QuantileTransformer-Uniform':"QuantileTransformer(output_distribution='uniform')",
'PowerTransformer-Yeo-Johnson':"PowerTransformer(method='yeo-johnson')",
'Normalizer':"Normalizer"}

scalers_df = pd.DataFrame(list(dict2.items()), columns=["Name","Sklearn_Class"])
s = scalers_df.style.set_properties(subset=["Name", "Sklearn_Class"], **{'text-align': 'left'})
s.set_table_styles([ dict(selector='th', props=[('text-align', 'left')] ) ])
# Out:
# <style  type="text/css" >
#     #T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0 th {
#           text-align: left;
#     }    #T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row0_col0 {
#             text-align:  left;
#         }    #T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row0_col1 {
#             text-align:  left;
#         }    #T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row1_col0 {
#             text-align:  left;
#         }    #T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row1_col1 {
#             text-align:  left;
#         }    #T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row2_col0 {
#             text-align:  left;
#         }    #T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row2_col1 {
#             text-align:  left;
#         }    #T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row3_col0 {
#             text-align:  left;
#         }    #T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row3_col1 {
#             text-align:  left;
#         }    #T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row4_col0 {
#             text-align:  left;
#         }    #T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row4_col1 {
#             text-align:  left;
#         }    #T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row5_col0 {
#             text-align:  left;
#         }    #T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row5_col1 {
#             text-align:  left;
#         }    #T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row6_col0 {
#             text-align:  left;
#         }    #T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row6_col1 {
#             text-align:  left;
#         }    #T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row7_col0 {
#             text-align:  left;
#         }    #T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row7_col1 {
#             text-align:  left;
#         }</style>
# <table id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Name</th>
#         <th class="col_heading level0 col1" >Sklearn_Class</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row0_col0" class="data row0 col0" >StandardScaler</td>
#         <td id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row0_col1" class="data row0 col1" >StandardScaler</td>
#     </tr>    <tr>
#         <th id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row1_col0" class="data row1 col0" >MinMaxScaler</td>
#         <td id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row1_col1" class="data row1 col1" >MinMaxScaler</td>
#     </tr>    <tr>
#         <th id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row2_col0" class="data row2 col0" >MaxAbsScaler</td>
#         <td id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row2_col1" class="data row2 col1" >MaxAbsScaler</td>
#     </tr>    <tr>
#         <th id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row3_col0" class="data row3 col0" >RobustScaler</td>
#         <td id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row3_col1" class="data row3 col1" >RobustScaler</td>
#     </tr>    <tr>
#         <th id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row4_col0" class="data row4 col0" >QuantileTransformer-Normal</td>
#         <td id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row4_col1" class="data row4 col1" >QuantileTransformer(output_distribution='normal')</td>
#     </tr>    <tr>
#         <th id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row5_col0" class="data row5 col0" >QuantileTransformer-Uniform</td>
#         <td id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row5_col1" class="data row5 col1" >QuantileTransformer(output_distribution='uniform')</td>
#     </tr>    <tr>
#         <th id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row6_col0" class="data row6 col0" >PowerTransformer-Yeo-Johnson</td>
#         <td id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row6_col1" class="data row6 col1" >PowerTransformer(method='yeo-johnson')</td>
#     </tr>    <tr>
#         <th id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row7_col0" class="data row7 col0" >Normalizer</td>
#         <td id="T_fc7a15f4_552c_11e9_a3e5_d0c5d31508a0row7_col1" class="data row7 col1" >Normalizer</td>
#     </tr></tbody>
# </table>

# %%
# Print table for the Medium article
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 100000)
pd.options.display.max_rows
pd.set_option('display.max_colwidth', -1)

dict2 = {'LR': "LogisticRegression",
'LDA':"LinearDiscriminantAnalysis",
'KNN':"KNeighborsClassifier",
'CART':"DecisionTreeClassifier",
'NB':"GaussianNB",
'SVM':"SVC",
'RF':"RandomForestClassifier",
'MLP':"MLPClassifier"}

scalers_df = pd.DataFrame(list(dict2.items()), columns=["Name","Sklearn_Class"])
s = scalers_df.style.set_properties(subset=["Name", "Sklearn_Class"], **{'text-align': 'left'})
s.set_table_styles([ dict(selector='th', props=[('text-align', 'left')] ) ])
# Out:
# <style  type="text/css" >
#     #T_fc7d4968_552c_11e9_90f6_d0c5d31508a0 th {
#           text-align: left;
#     }    #T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row0_col0 {
#             text-align:  left;
#         }    #T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row0_col1 {
#             text-align:  left;
#         }    #T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row1_col0 {
#             text-align:  left;
#         }    #T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row1_col1 {
#             text-align:  left;
#         }    #T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row2_col0 {
#             text-align:  left;
#         }    #T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row2_col1 {
#             text-align:  left;
#         }    #T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row3_col0 {
#             text-align:  left;
#         }    #T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row3_col1 {
#             text-align:  left;
#         }    #T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row4_col0 {
#             text-align:  left;
#         }    #T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row4_col1 {
#             text-align:  left;
#         }    #T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row5_col0 {
#             text-align:  left;
#         }    #T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row5_col1 {
#             text-align:  left;
#         }    #T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row6_col0 {
#             text-align:  left;
#         }    #T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row6_col1 {
#             text-align:  left;
#         }    #T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row7_col0 {
#             text-align:  left;
#         }    #T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row7_col1 {
#             text-align:  left;
#         }</style>
# <table id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Name</th>
#         <th class="col_heading level0 col1" >Sklearn_Class</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row0_col0" class="data row0 col0" >LR</td>
#         <td id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row0_col1" class="data row0 col1" >LogisticRegression</td>
#     </tr>    <tr>
#         <th id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row1_col0" class="data row1 col0" >LDA</td>
#         <td id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row1_col1" class="data row1 col1" >LinearDiscriminantAnalysis</td>
#     </tr>    <tr>
#         <th id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row2_col0" class="data row2 col0" >KNN</td>
#         <td id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row2_col1" class="data row2 col1" >KNeighborsClassifier</td>
#     </tr>    <tr>
#         <th id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row3_col0" class="data row3 col0" >CART</td>
#         <td id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row3_col1" class="data row3 col1" >DecisionTreeClassifier</td>
#     </tr>    <tr>
#         <th id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row4_col0" class="data row4 col0" >NB</td>
#         <td id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row4_col1" class="data row4 col1" >GaussianNB</td>
#     </tr>    <tr>
#         <th id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row5_col0" class="data row5 col0" >SVM</td>
#         <td id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row5_col1" class="data row5 col1" >SVC</td>
#     </tr>    <tr>
#         <th id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row6_col0" class="data row6 col0" >RF</td>
#         <td id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row6_col1" class="data row6 col1" >RandomForestClassifier</td>
#     </tr>    <tr>
#         <th id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row7_col0" class="data row7 col0" >MLP</td>
#         <td id="T_fc7d4968_552c_11e9_90f6_d0c5d31508a0row7_col1" class="data row7 col1" >MLPClassifier</td>
#     </tr></tbody>
# </table>

# %%
import operator

cols_max_vals = {}
cols_max_row_names = {}
for col in list(pivot_t):
    row_name = pivot_t[col].idxmax()
    cell_val = pivot_t[col].max()
    cols_max_vals[col] = cell_val
    cols_max_row_names[col] = row_name
    
sorted_cols_max_vals = sorted(cols_max_vals.items(), key=lambda kv: kv[1], reverse=True)

print("Best classifiers sorted:\n")
counter = 1
for model, score in sorted_cols_max_vals:
    print(str(counter) + ". " + model + " + " +cols_max_row_names[model] + " : " +str(score))
    counter +=1
# Out:
# Best classifiers sorted:
#
# 1. SVM + StandardScaler : 0.849
# 2. MLP + PowerTransformer-Yeo-Johnson : 0.839
# 3. KNN + MinMaxScaler : 0.813
# 4. LR + QuantileTransformer-Uniform : 0.808
# 5. NB + PowerTransformer-Yeo-Johnson : 0.752
# 6. LDA + PowerTransformer-Yeo-Johnson : 0.747
# 7. CART + QuantileTransformer-Uniform : 0.74
# 8. RF + Normalizer : 0.723

# %% [markdown]
# # 3. Classifier+Scaling+PCA

# %%
import operator
temp = results_df.copy()
temp["model"] = results_df["Classifier_Name"].apply(lambda sen: sen.split("_")[1])
temp["scaler"] = results_df["Classifier_Name"].apply(lambda sen: sen.split("_")[0])

def df_style(val):
    return 'font-weight: 800'
    

pivot_t = pd.pivot_table(temp, values='CV_mean', index=["scaler"], columns=['model'], aggfunc=np.sum)
pivot_t_bold = pivot_t.style.applymap(df_style,
                      subset=pd.IndexSlice[pivot_t["CART"].idxmax(),"CART"])
for col in list(pivot_t):
    pivot_t_bold = pivot_t_bold.applymap(df_style,
                      subset=pd.IndexSlice[pivot_t[col].idxmax(),col])
pivot_t_bold
# Out:
# <style  type="text/css" >
#     #T_fc89b75e_552c_11e9_956d_d0c5d31508a0row1_col3 {
#             font-weight:  800;
#         }    #T_fc89b75e_552c_11e9_956d_d0c5d31508a0row2_col1 {
#             font-weight:  800;
#         }    #T_fc89b75e_552c_11e9_956d_d0c5d31508a0row2_col2 {
#             font-weight:  800;
#         }    #T_fc89b75e_552c_11e9_956d_d0c5d31508a0row3_col12 {
#             font-weight:  800;
#         }    #T_fc89b75e_552c_11e9_956d_d0c5d31508a0row4_col4 {
#             font-weight:  800;
#         }    #T_fc89b75e_552c_11e9_956d_d0c5d31508a0row4_col8 {
#             font-weight:  800;
#         }    #T_fc89b75e_552c_11e9_956d_d0c5d31508a0row4_col10 {
#             font-weight:  800;
#         }    #T_fc89b75e_552c_11e9_956d_d0c5d31508a0row4_col11 {
#             font-weight:  800;
#         }    #T_fc89b75e_552c_11e9_956d_d0c5d31508a0row5_col13 {
#             font-weight:  800;
#         }    #T_fc89b75e_552c_11e9_956d_d0c5d31508a0row6_col0 {
#             font-weight:  800;
#             font-weight:  800;
#         }    #T_fc89b75e_552c_11e9_956d_d0c5d31508a0row6_col5 {
#             font-weight:  800;
#         }    #T_fc89b75e_552c_11e9_956d_d0c5d31508a0row6_col6 {
#             font-weight:  800;
#         }    #T_fc89b75e_552c_11e9_956d_d0c5d31508a0row6_col7 {
#             font-weight:  800;
#         }    #T_fc89b75e_552c_11e9_956d_d0c5d31508a0row7_col15 {
#             font-weight:  800;
#         }    #T_fc89b75e_552c_11e9_956d_d0c5d31508a0row8_col9 {
#             font-weight:  800;
#         }    #T_fc89b75e_552c_11e9_956d_d0c5d31508a0row8_col14 {
#             font-weight:  800;
#         }</style>
# <table id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0" >
# <thead>    <tr>
#         <th class="index_name level0" >model</th>
#         <th class="col_heading level0 col0" >CART</th>
#         <th class="col_heading level0 col1" >CART-PCA</th>
#         <th class="col_heading level0 col2" >KNN</th>
#         <th class="col_heading level0 col3" >KNN-PCA</th>
#         <th class="col_heading level0 col4" >LDA</th>
#         <th class="col_heading level0 col5" >LDA-PCA</th>
#         <th class="col_heading level0 col6" >LR</th>
#         <th class="col_heading level0 col7" >LR-PCA</th>
#         <th class="col_heading level0 col8" >MLP</th>
#         <th class="col_heading level0 col9" >MLP-PCA</th>
#         <th class="col_heading level0 col10" >NB</th>
#         <th class="col_heading level0 col11" >NB-PCA</th>
#         <th class="col_heading level0 col12" >RF</th>
#         <th class="col_heading level0 col13" >RF-PCA</th>
#         <th class="col_heading level0 col14" >SVM</th>
#         <th class="col_heading level0 col15" >SVM-PCA</th>
#     </tr>    <tr>
#         <th class="index_name level0" >scaler</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0level0_row0" class="row_heading level0 row0" ></th>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row0_col0" class="data row0 col0" >0.735</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row0_col1" class="data row0 col1" >0.657</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row0_col2" class="data row0 col2" >0.753</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row0_col3" class="data row0 col3" >0.742</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row0_col4" class="data row0 col4" >0.699</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row0_col5" class="data row0 col5" >0.704</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row0_col6" class="data row0 col6" >0.754</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row0_col7" class="data row0 col7" >0.699</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row0_col8" class="data row0 col8" >0.778</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row0_col9" class="data row0 col9" >0.705</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row0_col10" class="data row0 col10" >0.657</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row0_col11" class="data row0 col11" >0.699</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row0_col12" class="data row0 col12" >0.71</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row0_col13" class="data row0 col13" >0.711</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row0_col14" class="data row0 col14" >0.608</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row0_col15" class="data row0 col15" >0.699</td>
#     </tr>    <tr>
#         <th id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0level0_row1" class="row_heading level0 row1" >MaxAbsScaler</th>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row1_col0" class="data row1 col0" >0.735</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row1_col1" class="data row1 col1" >0.717</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row1_col2" class="data row1 col2" >0.808</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row1_col3" class="data row1 col3" >0.777</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row1_col4" class="data row1 col4" >0.699</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row1_col5" class="data row1 col5" >0.759</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row1_col6" class="data row1 col6" >0.778</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row1_col7" class="data row1 col7" >0.759</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row1_col8" class="data row1 col8" >0.767</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row1_col9" class="data row1 col9" >0.741</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row1_col10" class="data row1 col10" >0.657</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row1_col11" class="data row1 col11" >0.753</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row1_col12" class="data row1 col12" >0.71</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row1_col13" class="data row1 col13" >0.729</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row1_col14" class="data row1 col14" >0.705</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row1_col15" class="data row1 col15" >0.759</td>
#     </tr>    <tr>
#         <th id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0level0_row2" class="row_heading level0 row2" >MinMaxScaler</th>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row2_col0" class="data row2 col0" >0.735</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row2_col1" class="data row2 col1" >0.742</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row2_col2" class="data row2 col2" >0.813</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row2_col3" class="data row2 col3" >0.759</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row2_col4" class="data row2 col4" >0.699</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row2_col5" class="data row2 col5" >0.753</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row2_col6" class="data row2 col6" >0.778</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row2_col7" class="data row2 col7" >0.753</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row2_col8" class="data row2 col8" >0.767</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row2_col9" class="data row2 col9" >0.747</td>
#         <td id="T_fc89b75e_552c_11e9_956d_d0c5d31508a0row2_col10" class=

# %% [markdown]
# # Classifiers+Scaling+PCA+Hyperparameter tuning

# %% [markdown]
# I hypertune the parameters only on the Sonar dataset

# %%
import operator

import os
import pandas as pd

results_hyper_file = "sonar_results_hypertuned.csv"
results_hyper_df = pd.read_csv(os.path.join("..", "..", "data", "processed", results_hyper_file)).dropna().round(3)


temp = results_hyper_df.copy()
temp["model"] = results_hyper_df["Classifier_Name"].apply(lambda sen: sen.split("_")[1])
temp["scaler"] = results_hyper_df["Classifier_Name"].apply(lambda sen: sen.split("_")[0])

def df_style(val):
    return 'font-weight: 800'
    

pivot_t = pd.pivot_table(temp, values='CV_mean', index=["scaler"], columns=['model'], aggfunc=np.sum)
pivot_t_bold = pivot_t.style.applymap(df_style,
                      subset=pd.IndexSlice[pivot_t["KNN"].idxmax(),"KNN"])
for col in list(pivot_t):
    pivot_t_bold = pivot_t_bold.applymap(df_style,
                      subset=pd.IndexSlice[pivot_t[col].idxmax(),col])
pivot_t_bold
# Out:
# <style  type="text/css" >
#     #T_fc9884b8_552c_11e9_a915_d0c5d31508a0row0_col0 {
#             font-weight:  800;
#         }    #T_fc9884b8_552c_11e9_a915_d0c5d31508a0row1_col9 {
#             font-weight:  800;
#         }    #T_fc9884b8_552c_11e9_a915_d0c5d31508a0row3_col1 {
#             font-weight:  800;
#         }    #T_fc9884b8_552c_11e9_a915_d0c5d31508a0row3_col8 {
#             font-weight:  800;
#         }    #T_fc9884b8_552c_11e9_a915_d0c5d31508a0row3_col12 {
#             font-weight:  800;
#         }    #T_fc9884b8_552c_11e9_a915_d0c5d31508a0row4_col5 {
#             font-weight:  800;
#         }    #T_fc9884b8_552c_11e9_a915_d0c5d31508a0row4_col10 {
#             font-weight:  800;
#         }    #T_fc9884b8_552c_11e9_a915_d0c5d31508a0row4_col11 {
#             font-weight:  800;
#         }    #T_fc9884b8_552c_11e9_a915_d0c5d31508a0row5_col2 {
#             font-weight:  800;
#             font-weight:  800;
#         }    #T_fc9884b8_552c_11e9_a915_d0c5d31508a0row5_col4 {
#             font-weight:  800;
#         }    #T_fc9884b8_552c_11e9_a915_d0c5d31508a0row5_col6 {
#             font-weight:  800;
#         }    #T_fc9884b8_552c_11e9_a915_d0c5d31508a0row5_col7 {
#             font-weight:  800;
#         }    #T_fc9884b8_552c_11e9_a915_d0c5d31508a0row6_col3 {
#             font-weight:  800;
#         }    #T_fc9884b8_552c_11e9_a915_d0c5d31508a0row6_col13 {
#             font-weight:  800;
#         }</style>
# <table id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0" >
# <thead>    <tr>
#         <th class="index_name level0" >model</th>
#         <th class="col_heading level0 col0" >CART</th>
#         <th class="col_heading level0 col1" >CART-PCA</th>
#         <th class="col_heading level0 col2" >KNN</th>
#         <th class="col_heading level0 col3" >KNN-PCA</th>
#         <th class="col_heading level0 col4" >LDA</th>
#         <th class="col_heading level0 col5" >LDA-PCA</th>
#         <th class="col_heading level0 col6" >LR</th>
#         <th class="col_heading level0 col7" >LR-PCA</th>
#         <th class="col_heading level0 col8" >MLP</th>
#         <th class="col_heading level0 col9" >MLP-PCA</th>
#         <th class="col_heading level0 col10" >RF</th>
#         <th class="col_heading level0 col11" >RF-PCA</th>
#         <th class="col_heading level0 col12" >SVM</th>
#         <th class="col_heading level0 col13" >SVM-PCA</th>
#     </tr>    <tr>
#         <th class="index_name level0" >scaler</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0level0_row0" class="row_heading level0 row0" ></th>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row0_col0" class="data row0 col0" >0.734</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row0_col1" class="data row0 col1" >0.704</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row0_col2" class="data row0 col2" >0.85</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row0_col3" class="data row0 col3" >0.771</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row0_col4" class="data row0 col4" >0.77</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row0_col5" class="data row0 col5" >0.676</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row0_col6" class="data row0 col6" >0.76</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row0_col7" class="data row0 col7" >0.689</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row0_col8" class="data row0 col8" >0.734</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row0_col9" class="data row0 col9" >0.651</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row0_col10" class="data row0 col10" >0.771</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row0_col11" class="data row0 col11" >0.699</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row0_col12" class="data row0 col12" >0.789</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row0_col13" class="data row0 col13" >0.67</td>
#     </tr>    <tr>
#         <th id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0level0_row1" class="row_heading level0 row1" >MaxAbsScaler</th>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row1_col0" class="data row1 col0" >0.734</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row1_col1" class="data row1 col1" >0.723</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row1_col2" class="data row1 col2" >0.843</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row1_col3" class="data row1 col3" >0.741</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row1_col4" class="data row1 col4" >0.765</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row1_col5" class="data row1 col5" >0.76</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row1_col6" class="data row1 col6" >0.736</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row1_col7" class="data row1 col7" >0.766</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row1_col8" class="data row1 col8" >0.728</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row1_col9" class="data row1 col9" >0.754</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row1_col10" class="data row1 col10" >0.776</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row1_col11" class="data row1 col11" >0.758</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row1_col12" class="data row1 col12" >0.759</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row1_col13" class="data row1 col13" >0.743</td>
#     </tr>    <tr>
#         <th id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0level0_row2" class="row_heading level0 row2" >MinMaxScaler</th>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row2_col0" class="data row2 col0" >0.734</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row2_col1" class="data row2 col1" >0.657</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row2_col2" class="data row2 col2" >0.837</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row2_col3" class="data row2 col3" >0.753</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row2_col4" class="data row2 col4" >0.782</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row2_col5" class="data row2 col5" >0.754</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row2_col6" class="data row2 col6" >0.711</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row2_col7" class="data row2 col7" >0.766</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row2_col8" class="data row2 col8" >0.746</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row2_col9" class="data row2 col9" >0.742</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row2_col10" class="data row2 col10" >0.776</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row2_col11" class="data row2 col11" >0.722</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row2_col12" class="data row2 col12" >0.735</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row2_col13" class="data row2 col13" >0.737</td>
#     </tr>    <tr>
#         <th id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0level0_row3" class="row_heading level0 row3" >PowerTransformer-Yeo-Johnson</th>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row3_col0" class="data row3 col0" >0.65</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row3_col1" class="data row3 col1" >0.74</td>
#         <td id="T_fc9884b8_552c_11e9_a915_d0c5d31508a0row3_col2" class="data row3 col2" >0.874<
