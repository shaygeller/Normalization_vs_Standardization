# %% [markdown]
# # Normalization vs Standardization  - Quantitative analysis

# %% [markdown]
# ## Table of Contests
# * [0. Why are we here?](#why_are_we_here)
# * [1. Out-of-the-box classifiers](#Out-of-the-box_classifier)
# * [2. Classifier + Scaling](#Classifiers_Scaling)
# * [3. Classifier + Scaling + PCA](#Classifiers_Scaling_PCA)
# * [4. Classifier + Scaling + PCA + Hyperparameter Tuning](#Classifiers_Scaling_PCA_Hyper_param)

# %% [markdown]
# <a id="why_are_we_here"></a>
# # 0. Why are we here?

# %% [markdown]
# First, I was trying to understand what is the difference between Normalization and Standardization.<br>
# So, I encountered this excellent <a href="https://sebastianraschka.com/Articles/2014_about_feature_scaling.html">blog</a> that answered my question. <br>
# There is also a great explanation about why to scale features for neural networks by Hinton <a href="https://www.youtube.com/watch?v=Xjtu1L7RwVM&list=PLoRl3Ht4JOcdU872GhiYWf6jwrk_SNhz9&index=26">here</a>
#
# So, now I know the difference between Normalization and Standardization. That's it? No! <br>
# I saw a lot of ML pipelines tutorials that use StandardScaler (usually called Z-score Standardization) or MinMaxScaler (usually called min-max Normalization) to scale features. However, when I checked Sklearn, I saw that there are lots of different scaling methods. Why no one uses other scaling techniques? Does StandardScaler or MinMaxScaler are the best scaling methods? <br>
# I didn't see any explanation in the tutorials about why or when to use each one of them, so I ran some experiments to check all of them as a good DataScientist should do. <b>This is what this notebook is all about</b>
#
#
# Usually, I prefer more solid mathematical explanations, but I couldn't find one that distinguishes between more than these two scaling techniques, and how each technique affect different well-known classifiers, so I ran a quantitative experiment.<br>
# If you can point me to some mathematical reading, please email me at shayzm1@gmail.com <br>
#
# If you find some mistakes or have proposals to improve the coverage or the validity of the experiment, please notify me.

# %% [markdown]
# ## Project details

# %% [markdown]
# Like many DS projects, lets read some data and check several out-of-the-box classifiers.<br>
# As a preprocessing step, I already calculated all the results (it takes some time). So we only load the results file and work with it.<br>
#
#
# The classifiers I used are taken from the Sklearn library and denoted as:<br>
# - 'LR', LogisticRegression <br>
# - 'LDA', LinearDiscriminantAnalysis <br>
# - 'KNN', KNeighborsClassifier<br>
# - 'CART', DecisionTreeClassifier<br>
# - 'NB', GaussianNB<br>
# - 'SVM', SVC<br>
# - 'RF', RandomForestClassifier<br>
# - 'MLP', MLPClassifier (Multi Layer Perceptron - Neural Network)<br>
#
#
# The scalers and normalizers I used are also taken from Sklearn library and denoted as:<br>
# - 'StandardScaler', StandardScaler<br>
# - 'MinMaxScaler', MinMaxScaler<br>
# - 'MaxAbsScaler', MaxAbsScaler<br>
# - 'RobustScaler', RobustScaler<br>
# - 'QuantileTransformer-Normal', QuantileTransformer(output_distribution='normal')<br>
# - 'QuantileTransformer-Uniform', QuantileTransformer(output_distribution='uniform')<br>
# - 'PowerTransformer-Yeo-Johnson', PowerTransformer(method='yeo-johnson')<br>
# - 'Normalizer', Normalizer<br>
#
#
# The code that produces the results can be found here:<br>
# TODO: Add link to github
#
# The dataset: TODO: Add explanation about the dataset
#
# Experiment  details: <br>
# - I randomly split the data to train-test sets of 80%-20% respectively. <br>
# - Then I used only the train part. I left the test for further results. <br>
# - I do not discuss the results on the test set here. Usually, the test set should be kept hidden, and all of our conclusions about our classifiers should be derived only from the cross-validation scores.<br>
# - All results are accuracy scores on 10-fold random cross-validation splits from the <b>train set</b>. <br>
#  - In part 4, I performed nested cross-validation. One inner cross-validation with 5 random splits for hyperparameter tuning, and another outer CV with 10 random splits to get the model's score using the best parameters. Also in this part, all data taken only from the train set. <br>
# - The same seed was used when needed for reproducibility.

# %% [markdown]
# ### Let's read the results file

# %%
import os
import pandas as pd

results_file = "sonar_results.csv"
results_df = pd.read_csv(os.path.join("..","data","processed",results_file)).dropna().round(3)
results_df
# Out:
#     Dataset                       Classifier_Name  CV_mean  CV_std  Test_acc
# 0     sonar                                   _LR    0.754   0.114     0.714
# 1     sonar                     StandardScaler_LR    0.742   0.105     0.833
# 2     sonar                       MinMaxScaler_LR    0.778   0.121     0.762
# 3     sonar                       MaxAbsScaler_LR    0.778   0.121     0.762
# 4     sonar                       RobustScaler_LR    0.735   0.077     0.810
# 5     sonar         QuantileTransformer-Normal_LR    0.718   0.135     0.810
# 6     sonar        QuantileTransformer-Uniform_LR    0.808   0.117     0.786
# 7     sonar       PowerTransformer-Yeo-Johnson_LR    0.760   0.089     0.833
# 8     sonar                         Normalizer_LR    0.699   0.097     0.690
# 10    sonar                               _LR-PCA    0.699   0.102     0.619
# 11    sonar                 StandardScaler_LR-PCA    0.753   0.147     0.738
# 12    sonar                   MinMaxScaler_LR-PCA    0.753   0.145     0.714
# 13    sonar                   MaxAbsScaler_LR-PCA    0.759   0.142     0.714
# 14    sonar                   RobustScaler_LR-PCA    0.734   0.131     0.738
# 15    sonar     QuantileTransformer-Normal_LR-PCA    0.741   0.155     0.714
# 16    sonar    QuantileTransformer-Uniform_LR-PCA    0.789   0.117     0.738
# 17    sonar   PowerTransformer-Yeo-Johnson_LR-PCA    0.782   0.117     0.714
# 18    sonar                     Normalizer_LR-PCA    0.631   0.069     0.571
# 20    sonar                                  _LDA    0.699   0.132     0.833
# 21    sonar                    StandardScaler_LDA    0.699   0.132     0.833
# 22    sonar                      MinMaxScaler_LDA    0.699   0.132     0.833
# 23    sonar                      MaxAbsScaler_LDA    0.699   0.132     0.833
# 24    sonar                      RobustScaler_LDA    0.699   0.132     0.833
# 25    sonar        QuantileTransformer-Normal_LDA    0.694   0.156     0.738
# 26    sonar       QuantileTransformer-Uniform_LDA    0.742   0.098     0.786
# 27    sonar      PowerTransformer-Yeo-Johnson_LDA    0.747   0.096     0.786
# 28    sonar                        Normalizer_LDA    0.692   0.115     0.833
# 30    sonar                              _LDA-PCA    0.704   0.093     0.643
# 31    sonar                StandardScaler_LDA-PCA    0.741   0.143     0.714
# 32    sonar                  MinMaxScaler_LDA-PCA    0.753   0.145     0.714
# ..      ...                                   ...      ...     ...       ...
# 126   sonar        QuantileTransformer-Uniform_RF    0.717   0.135     0.810
# 127   sonar       PowerTransformer-Yeo-Johnson_RF    0.710   0.126     0.810
# 128   sonar                         Normalizer_RF    0.723   0.117     0.762
# 130   sonar                               _RF-PCA    0.711   0.096     0.786
# 131   sonar                 StandardScaler_RF-PCA    0.675   0.120     0.762
# 132   sonar                   MinMaxScaler_RF-PCA    0.728   0.118     0.738
# 133   sonar                   MaxAbsScaler_RF-PCA    0.729   0.124     0.810
# 134   sonar                   RobustScaler_RF-PCA    0.703   0.149     0.786
# 135   sonar     QuantileTransformer-Normal_RF-PCA    0.766   0.105     0.833
# 136   sonar    QuantileTransformer-Uniform_RF-PCA    0.668   0.137     0.810
# 137   sonar   PowerTransformer-Yeo-Johnson_RF-PCA    0.710   0.128     0.762
# 138   sonar                     Normalizer_RF-PCA    0.643   0.086     0.643
# 140   sonar                                  _MLP    0.778   0.125     0.833
# 141   sonar                    StandardScaler_MLP    0.820   0.084     0.881
# 142   sonar                      MinMaxScaler_MLP    0.767   0.143     0.810
# 143   sonar                      MaxAbsScaler_MLP    0.767   0.143     0.810
# 144   sonar                      RobustScaler_MLP    0.808   0.088     0.881
# 145   sonar        QuantileTransformer-Normal_MLP    0.808   0.117     0.833
# 146   sonar       QuantileTransformer-Uniform_MLP    0.808   0.106     0.810
# 147   sonar      PowerTransformer-Yeo-Johnson_MLP    0.839   0.111     0.881
# 148   sonar                        Normalizer_MLP    0.724   0.132     0.762
# 150   sonar                              _MLP-PCA    0.705   0.085     0.738
# 151   sonar                StandardScaler_MLP-PCA    0.777   0.091     0.762
# 152   sonar                  MinMaxScaler_MLP-PCA    0.747   0.110     0.786
# 153   sonar                  MaxAbsScaler_MLP-PCA    0.741   0.108     0.786
# 154   sonar                  RobustScaler_MLP-PCA    0.771   0.089     0.810
# 155   sonar    QuantileTransformer-Normal_MLP-PCA    0.729   0.120     0.810
# 156   sonar   QuantileTransformer-Uniform_MLP-PCA    0.776   0.104     0.786
# 157   sonar  PowerTransformer-Yeo-Johnson_MLP-PCA    0.770   0.123     0.786
# 158   sonar                    Normalizer_MLP-PCA    0.619   0.097     0.571
#
# [144 rows x 5 columns]

# %% [markdown]
# <a id="Out-of-the-box_classifier"></a>
# # 1. Out-of-the-box classifiers

# %%
import operator
results_df.loc[operator.and_(results_df["Classifier_Name"].str.startswith("_"), ~results_df["Classifier_Name"].str.endswith("PCA"))].dropna()
# Out:
#     Dataset Classifier_Name  CV_mean  CV_std  Test_acc
# 0     sonar             _LR    0.754   0.114     0.714
# 20    sonar            _LDA    0.699   0.132     0.833
# 40    sonar            _KNN    0.753   0.081     0.762
# 60    sonar           _CART    0.735   0.067     0.810
# 80    sonar             _NB    0.657   0.131     0.690
# 100   sonar            _SVM    0.608   0.116     0.738
# 120   sonar             _RF    0.710   0.126     0.810
# 140   sonar            _MLP    0.778   0.125     0.833

# %% [markdown]
# Nice results.
# We can see that at the moment, MLF is on the lead.
#
# Now, let's see how different scaling methods change the scores for each classifier

# %% [markdown]
# <a id="Classifiers_Scaling"></a>
# # 2. Classifiers+Scaling

# %%
import operator
temp = results_df.loc[~results_df["Classifier_Name"].str.endswith("PCA")].dropna()
temp["model"] = results_df["Classifier_Name"].apply(lambda sen: sen.split("_")[1])
temp["scaler"] = results_df["Classifier_Name"].apply(lambda sen: sen.split("_")[0])

def df_style(val):
    return 'font-weight: 800'
    

pivot_t = pd.pivot_table(temp, values='CV_mean', index=["scaler"], columns=['model'], aggfunc=np.sum)
pivot_t_bold = pivot_t.style.applymap(df_style,
                      subset=pd.IndexSlice[pivot_t["CART"].idxmax(),"CART"])
for col in list(pivot_t):
    pivot_t_bold = pivot_t_bold.applymap(df_style,
                      subset=pd.IndexSlice[pivot_t[col].idxmax(),col])
pivot_t_bold
# Out:
# <style  type="text/css" >
#     #T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row2_col1 {
#             font-weight:  800;
#         }    #T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row3_col6 {
#             font-weight:  800;
#         }    #T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row4_col2 {
#             font-weight:  800;
#         }    #T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row4_col4 {
#             font-weight:  800;
#         }    #T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row4_col5 {
#             font-weight:  800;
#         }    #T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row6_col0 {
#             font-weight:  800;
#             font-weight:  800;
#         }    #T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row6_col3 {
#             font-weight:  800;
#         }    #T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row8_col7 {
#             font-weight:  800;
#         }</style>
# <table id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0" >
# <thead>    <tr>
#         <th class="index_name level0" >model</th>
#         <th class="col_heading level0 col0" >CART</th>
#         <th class="col_heading level0 col1" >KNN</th>
#         <th class="col_heading level0 col2" >LDA</th>
#         <th class="col_heading level0 col3" >LR</th>
#         <th class="col_heading level0 col4" >MLP</th>
#         <th class="col_heading level0 col5" >NB</th>
#         <th class="col_heading level0 col6" >RF</th>
#         <th class="col_heading level0 col7" >SVM</th>
#     </tr>    <tr>
#         <th class="index_name level0" >scaler</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0level0_row0" class="row_heading level0 row0" ></th>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row0_col0" class="data row0 col0" >0.735</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row0_col1" class="data row0 col1" >0.753</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row0_col2" class="data row0 col2" >0.699</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row0_col3" class="data row0 col3" >0.754</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row0_col4" class="data row0 col4" >0.778</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row0_col5" class="data row0 col5" >0.657</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row0_col6" class="data row0 col6" >0.71</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row0_col7" class="data row0 col7" >0.608</td>
#     </tr>    <tr>
#         <th id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0level0_row1" class="row_heading level0 row1" >MaxAbsScaler</th>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row1_col0" class="data row1 col0" >0.735</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row1_col1" class="data row1 col1" >0.808</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row1_col2" class="data row1 col2" >0.699</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row1_col3" class="data row1 col3" >0.778</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row1_col4" class="data row1 col4" >0.767</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row1_col5" class="data row1 col5" >0.657</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row1_col6" class="data row1 col6" >0.71</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row1_col7" class="data row1 col7" >0.705</td>
#     </tr>    <tr>
#         <th id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0level0_row2" class="row_heading level0 row2" >MinMaxScaler</th>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row2_col0" class="data row2 col0" >0.735</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row2_col1" class="data row2 col1" >0.813</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row2_col2" class="data row2 col2" >0.699</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row2_col3" class="data row2 col3" >0.778</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row2_col4" class="data row2 col4" >0.767</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row2_col5" class="data row2 col5" >0.657</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row2_col6" class="data row2 col6" >0.71</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row2_col7" class="data row2 col7" >0.711</td>
#     </tr>    <tr>
#         <th id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0level0_row3" class="row_heading level0 row3" >Normalizer</th>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row3_col0" class="data row3 col0" >0.716</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row3_col1" class="data row3 col1" >0.765</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row3_col2" class="data row3 col2" >0.692</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row3_col3" class="data row3 col3" >0.699</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row3_col4" class="data row3 col4" >0.724</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row3_col5" class="data row3 col5" >0.662</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row3_col6" class="data row3 col6" >0.723</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row3_col7" class="data row3 col7" >0.524</td>
#     </tr>    <tr>
#         <th id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0level0_row4" class="row_heading level0 row4" >PowerTransformer-Yeo-Johnson</th>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row4_col0" class="data row4 col0" >0.729</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row4_col1" class="data row4 col1" >0.813</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row4_col2" class="data row4 col2" >0.747</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row4_col3" class="data row4 col3" >0.76</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row4_col4" class="data row4 col4" >0.839</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row4_col5" class="data row4 col5" >0.752</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row4_col6" class="data row4 col6" >0.71</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row4_col7" class="data row4 col7" >0.814</td>
#     </tr>    <tr>
#         <th id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0level0_row5" class="row_heading level0 row5" >QuantileTransformer-Normal</th>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row5_col0" class="data row5 col0" >0.735</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row5_col1" class="data row5 col1" >0.783</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row5_col2" class="data row5 col2" >0.694</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row5_col3" class="data row5 col3" >0.718</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row5_col4" class="data row5 col4" >0.808</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row5_col5" class="data row5 col5" >0.752</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row5_col6" class="data row5 col6" >0.717</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row5_col7" class="data row5 col7" >0.832</td>
#     </tr>    <tr>
#         <th id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0level0_row6" class="row_heading level0 row6" >QuantileTransformer-Uniform</th>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row6_col0" class="data row6 col0" >0.74</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row6_col1" class="data row6 col1" >0.789</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row6_col2" class="data row6 col2" >0.742</td>
#         <td id="T_e33ca9b4_532c_11e9_b1d7_d0c5d31508a0row6_col3" class="data row6 col3" >0.808</td>
#         <

# %%
import operator

cols_max_vals = {}
cols_max_row_names = {}
for col in list(pivot_t):
    row_name = pivot_t[col].idxmax()
    cell_val = pivot_t[col].max()
    cols_max_vals[col] = cell_val
    cols_max_row_names[col] = row_name
    
sorted_cols_max_vals = sorted(cols_max_vals.items(), key=lambda kv: kv[1], reverse=True)

print("Best classifiers sorted:\n")
counter = 1
for model, score in sorted_cols_max_vals:
    print(str(counter) + ". " + model + " + " +cols_max_row_names[model] + " : " +str(score))
    counter +=1
# Out:
# Best classifiers sorted:
#
# 1. SVM + StandardScaler : 0.849
# 2. MLP + PowerTransformer-Yeo-Johnson : 0.839
# 3. KNN + MinMaxScaler : 0.813
# 4. LR + QuantileTransformer-Uniform : 0.808
# 5. NB + PowerTransformer-Yeo-Johnson : 0.752
# 6. LDA + PowerTransformer-Yeo-Johnson : 0.747
# 7. CART + QuantileTransformer-Uniform : 0.74
# 8. RF + Normalizer : 0.723

# %% [markdown]
# ## Let's analyze the results

# %% [markdown]
# 1. <b>There is no single scaling method to rule them all.</b>
#
#
# 2. We can see that scaling improved the results. SVM, MLP, KNN, and NB got a significant boost from different scaling methods.
#
#
# 3. Notice that NB, RF, LDA, CART are <b>unaffected</b> by some of the scaling methods. This is, of course, related to how each of the classifiers works. Trees are not affected by scaling because the splitting criterion first orders the values of each feature and then calculate the gini\entropy of the split. Some scaling methods don't affect this order so no change to the accuracy score. <br>
#     NB is not affected because the model's priors affected by the count in each class and not by the actual value. LDA fits a Gaussian density to each class, so the scaling doesn't matter either.
#
#
# 4. Some of the scaling methods, like QuantileTransformer-Uniform, doesn't preserve the exact order of the values in each feature, hence the change in score even in the above classifiers that were agnostic to other scaling methods.

# %% [markdown]
# <a id="Classifiers_Scaling_pca"></a>
# # 3. Classifier+Scaling+PCA
#
# We know that some well-known ML methods like PCA can benefit from scaling (<a href="https://sebastianraschka.com/Articles/2014_about_feature_scaling.html">blog</a>).
# Let's try adding PCA(n_components=4) to the pipeline and analyze the results.

# %%
import operator
temp = results_df.copy()
temp["model"] = results_df["Classifier_Name"].apply(lambda sen: sen.split("_")[1])
temp["scaler"] = results_df["Classifier_Name"].apply(lambda sen: sen.split("_")[0])

def df_style(val):
    return 'font-weight: 800'
    

pivot_t = pd.pivot_table(temp, values='CV_mean', index=["scaler"], columns=['model'], aggfunc=np.sum)
pivot_t_bold = pivot_t.style.applymap(df_style,
                      subset=pd.IndexSlice[pivot_t["CART"].idxmax(),"CART"])
for col in list(pivot_t):
    pivot_t_bold = pivot_t_bold.applymap(df_style,
                      subset=pd.IndexSlice[pivot_t[col].idxmax(),col])
pivot_t_bold
# Out:
# <style  type="text/css" >
#     #T_afcdac24_5321_11e9_b120_d0c5d31508a0row1_col3 {
#             font-weight:  800;
#         }    #T_afcdac24_5321_11e9_b120_d0c5d31508a0row2_col1 {
#             font-weight:  800;
#         }    #T_afcdac24_5321_11e9_b120_d0c5d31508a0row2_col2 {
#             font-weight:  800;
#         }    #T_afcdac24_5321_11e9_b120_d0c5d31508a0row3_col12 {
#             font-weight:  800;
#         }    #T_afcdac24_5321_11e9_b120_d0c5d31508a0row4_col4 {
#             font-weight:  800;
#         }    #T_afcdac24_5321_11e9_b120_d0c5d31508a0row4_col8 {
#             font-weight:  800;
#         }    #T_afcdac24_5321_11e9_b120_d0c5d31508a0row4_col10 {
#             font-weight:  800;
#         }    #T_afcdac24_5321_11e9_b120_d0c5d31508a0row4_col11 {
#             font-weight:  800;
#         }    #T_afcdac24_5321_11e9_b120_d0c5d31508a0row5_col13 {
#             font-weight:  800;
#         }    #T_afcdac24_5321_11e9_b120_d0c5d31508a0row6_col0 {
#             font-weight:  800;
#             font-weight:  800;
#         }    #T_afcdac24_5321_11e9_b120_d0c5d31508a0row6_col5 {
#             font-weight:  800;
#         }    #T_afcdac24_5321_11e9_b120_d0c5d31508a0row6_col6 {
#             font-weight:  800;
#         }    #T_afcdac24_5321_11e9_b120_d0c5d31508a0row6_col7 {
#             font-weight:  800;
#         }    #T_afcdac24_5321_11e9_b120_d0c5d31508a0row7_col15 {
#             font-weight:  800;
#         }    #T_afcdac24_5321_11e9_b120_d0c5d31508a0row8_col9 {
#             font-weight:  800;
#         }    #T_afcdac24_5321_11e9_b120_d0c5d31508a0row8_col14 {
#             font-weight:  800;
#         }</style>
# <table id="T_afcdac24_5321_11e9_b120_d0c5d31508a0" >
# <thead>    <tr>
#         <th class="index_name level0" >model</th>
#         <th class="col_heading level0 col0" >CART</th>
#         <th class="col_heading level0 col1" >CART-PCA</th>
#         <th class="col_heading level0 col2" >KNN</th>
#         <th class="col_heading level0 col3" >KNN-PCA</th>
#         <th class="col_heading level0 col4" >LDA</th>
#         <th class="col_heading level0 col5" >LDA-PCA</th>
#         <th class="col_heading level0 col6" >LR</th>
#         <th class="col_heading level0 col7" >LR-PCA</th>
#         <th class="col_heading level0 col8" >MLP</th>
#         <th class="col_heading level0 col9" >MLP-PCA</th>
#         <th class="col_heading level0 col10" >NB</th>
#         <th class="col_heading level0 col11" >NB-PCA</th>
#         <th class="col_heading level0 col12" >RF</th>
#         <th class="col_heading level0 col13" >RF-PCA</th>
#         <th class="col_heading level0 col14" >SVM</th>
#         <th class="col_heading level0 col15" >SVM-PCA</th>
#     </tr>    <tr>
#         <th class="index_name level0" >scaler</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_afcdac24_5321_11e9_b120_d0c5d31508a0level0_row0" class="row_heading level0 row0" ></th>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row0_col0" class="data row0 col0" >0.735</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row0_col1" class="data row0 col1" >0.657</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row0_col2" class="data row0 col2" >0.753</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row0_col3" class="data row0 col3" >0.742</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row0_col4" class="data row0 col4" >0.699</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row0_col5" class="data row0 col5" >0.704</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row0_col6" class="data row0 col6" >0.754</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row0_col7" class="data row0 col7" >0.699</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row0_col8" class="data row0 col8" >0.778</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row0_col9" class="data row0 col9" >0.705</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row0_col10" class="data row0 col10" >0.657</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row0_col11" class="data row0 col11" >0.699</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row0_col12" class="data row0 col12" >0.71</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row0_col13" class="data row0 col13" >0.711</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row0_col14" class="data row0 col14" >0.608</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row0_col15" class="data row0 col15" >0.699</td>
#     </tr>    <tr>
#         <th id="T_afcdac24_5321_11e9_b120_d0c5d31508a0level0_row1" class="row_heading level0 row1" >MaxAbsScaler</th>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row1_col0" class="data row1 col0" >0.735</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row1_col1" class="data row1 col1" >0.717</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row1_col2" class="data row1 col2" >0.808</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row1_col3" class="data row1 col3" >0.777</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row1_col4" class="data row1 col4" >0.699</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row1_col5" class="data row1 col5" >0.759</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row1_col6" class="data row1 col6" >0.778</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row1_col7" class="data row1 col7" >0.759</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row1_col8" class="data row1 col8" >0.767</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row1_col9" class="data row1 col9" >0.741</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row1_col10" class="data row1 col10" >0.657</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row1_col11" class="data row1 col11" >0.753</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row1_col12" class="data row1 col12" >0.71</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row1_col13" class="data row1 col13" >0.729</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row1_col14" class="data row1 col14" >0.705</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row1_col15" class="data row1 col15" >0.759</td>
#     </tr>    <tr>
#         <th id="T_afcdac24_5321_11e9_b120_d0c5d31508a0level0_row2" class="row_heading level0 row2" >MinMaxScaler</th>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row2_col0" class="data row2 col0" >0.735</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row2_col1" class="data row2 col1" >0.742</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row2_col2" class="data row2 col2" >0.813</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row2_col3" class="data row2 col3" >0.759</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row2_col4" class="data row2 col4" >0.699</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row2_col5" class="data row2 col5" >0.753</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row2_col6" class="data row2 col6" >0.778</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row2_col7" class="data row2 col7" >0.753</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row2_col8" class="data row2 col8" >0.767</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row2_col9" class="data row2 col9" >0.747</td>
#         <td id="T_afcdac24_5321_11e9_b120_d0c5d31508a0row2_col10" class=

# %% [markdown]
# ## Let's analyze the results

# %% [markdown]
# 1. We can see that PCA only improve LDA and RF, so PCA is not a magic solution.<br>
#     It's fine. We didn't hypertune the n_components parameter, and even if we did, PCA doesn't guarantee to improve predictions.
#
#
# 2. Most of the time scaling methods improve models with PCA, <b> but </b> no specific scaling method is in charge. <br>
#     Let's look at "QuantileTransformer-Uniform", the method with most of the high scores. <br>
#     In LDA-PCA it improved the results from 0.704 to 0.783 (8% jump in accuracy!), but in RF-PCA it makes things worse, from 0.711 to 0.668 (4.35% drop in accuracy!) <br>
#     On the other hand, using RF-PCA with "QuantileTransformer-Normal", improved the accuracy to 0.766 (5% jump in accuracy!) <br>
# 3. We can see that StandardScaler and MinMaxScaler achieve best scores only on 4 out of 16 cases. So one should think carefully what scaling method to choose, even as a default one.<br>
#
# <b>We can conclude that even though PCA is a known component that benefits from scaling, no single scaling method always improved our results, and some of them even cause harm</b>

# %% [markdown]
# <a id="Classifiers_Scaling_pca_hyper_param"></a>
#
# # Classifiers+Scaling+PCA+Hyperparameter tuning
#
# There were big differences in the accuracy score between different scaling methods for a given classifier. One can assume that when the hyperparameters are tuned, the difference between the scaling techniques will be minor and we can use StandardScaler or MinMaxScaler as used in many classification pipelines tutorials in the web. <br>
# Let's check that!

# %% [markdown]
# TODO
