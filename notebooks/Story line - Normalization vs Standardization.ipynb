# %% [markdown]
# # Normalization vs Standardization  - Quantitative analysis

# %% [markdown]
# ## Table of Contests
# * [0. Why are we here?](#why_are_we_here)
# * [1. Out-of-the-box classifiers](#Out-of-the-box_classifier)
# * [2. Classifier + Scaling](#Classifiers_Scaling)
# * [3. Classifier + Scaling + PCA](#Classifiers_Scaling_PCA)
# * [4. Classifier + Scaling + PCA + Hyperparameter Tuning](#Classifiers_Scaling_PCA_Hyper_param)

# %% [markdown]
# <a id="why_are_we_here"></a>
# # 0. Why are we here?

# %% [markdown]
# First, I was trying to understand what is the difference between Normalization and Standardization.<br>
# So, I encountered this excellent <a href="https://sebastianraschka.com/Articles/2014_about_feature_scaling.html">blog</a> that answered my question. <br>
# There is also a great explanation about why to scale features for neural networks by Hinton <a href="https://www.youtube.com/watch?v=Xjtu1L7RwVM&list=PLoRl3Ht4JOcdU872GhiYWf6jwrk_SNhz9&index=26">here</a>
#
# So, now I know the difference between Normalization and Standardization. That's it? No! <br>
# I saw a lot of ML pipelines tutorials that use StandardScaler (usually called Z-score Standardization) or MinMaxScaler (usually called min-max Normalization) to scale features. However, when I checked Sklearn, I saw that there are lots of different scaling methods. Why no one uses other scaling techniques? Does StandardScaler or MinMaxScaler are the best scaling methods? <br>
# I didn't see any explanation in the tutorials about why or when to use each one of them, so I ran some experiments to check all of them as a good DataScientist should do. <b>This is what this notebook is all about</b>
#
#
# Usually, I prefer more solid mathematical explanations, but I couldn't find one that distinguishes between more than these two scaling techniques, and how each technique affect different well-known classifiers, so I ran a quantitative experiment.<br>
# If you can point me to some mathematical reading, please email me at shayzm1@gmail.com <br>
#
# If you find some mistakes or have proposals to improve the coverage or the validity of the experiment, please notify me.

# %% [markdown]
# ## Project details

# %% [markdown]
# Like many DS projects, lets read some data and check several out-of-the-box classifiers.<br>
# As a preprocessing step, I already calculated all the results (it takes some time). So we only load the results file and work with it.<br>
#
#
# The classifiers I used are taken from the Sklearn library and denoted as:<br>
# - 'LR', LogisticRegression <br>
# - 'LDA', LinearDiscriminantAnalysis <br>
# - 'KNN', KNeighborsClassifier<br>
# - 'CART', DecisionTreeClassifier<br>
# - 'NB', GaussianNB<br>
# - 'SVM', SVC<br>
# - 'RF', RandomForestClassifier<br>
# - 'MLP', MLPClassifier (Multi Layer Perceptron - Neural Network)<br>
#
#
# The scalers and normalizers I used are also taken from Sklearn library and denoted as:<br>
# - 'StandardScaler', StandardScaler<br>
# - 'MinMaxScaler', MinMaxScaler<br>
# - 'MaxAbsScaler', MaxAbsScaler<br>
# - 'RobustScaler', RobustScaler<br>
# - 'QuantileTransformer-Normal', QuantileTransformer(output_distribution='normal')<br>
# - 'QuantileTransformer-Uniform', QuantileTransformer(output_distribution='uniform')<br>
# - 'PowerTransformer-Yeo-Johnson', PowerTransformer(method='yeo-johnson')<br>
# - 'Normalizer', Normalizer<br>
#
#
# The code that produces the results can be found here:<br>
# TODO: Add link to github
#
# The dataset: TODO: Add explanation about the dataset
#
# Experiment  details: <br>
# - I randomly split the data to train-test sets of 80%-20% respectively. <br>
# - Then I used only the train part. I left the test for further results. <br>
# - I do not discuss the results on the test set here. Usually, the test set should be kept hidden, and all of our conclusions about our classifiers should be derived only from the cross-validation scores.<br>
# - All results are accuracy scores on 10-fold random cross-validation splits from the <b>train set</b>. <br>
#  - In part 4, I performed nested cross-validation. One inner cross-validation with 5 random splits for hyperparameter tuning, and another outer CV with 10 random splits to get the model's score using the best parameters. Also in this part, all data taken only from the train set. <br>
# - The same seed was used when needed for reproducibility.

# %% [markdown]
# ### Let's read the results file

# %%
import os
import pandas as pd


# results_file = "sonar_results.csv"
results_file = "weatherAUS_results.csv"

results_df = pd.read_csv(os.path.join("..","data","processed",results_file)).dropna().round(3)
results_df
# Out:
#         Dataset                        Classifier_Name  CV_mean  CV_std  Test_score
# 0    weatherAUS  _LR                                    1.000    0.000   1.000
# 1    weatherAUS  StandardScaler_LR                      0.994    0.001   0.994
# 2    weatherAUS  MinMaxScaler_LR                        0.887    0.004   0.892
# 3    weatherAUS  MaxAbsScaler_LR                        0.887    0.005   0.890
# 4    weatherAUS  RobustScaler_LR                        1.000    0.000   1.000
# 5    weatherAUS  QuantileTransformer-Normal_LR          1.000    0.000   1.000
# 6    weatherAUS  QuantileTransformer-Uniform_LR         0.994    0.001   0.995
# 7    weatherAUS  PowerTransformer-Yeo-Johnson_LR        1.000    0.000   1.000
# 8    weatherAUS  Normalizer_LR                          0.827    0.004   0.835
# 10   weatherAUS  _LR-PCA                                0.850    0.005   0.852
# 11   weatherAUS  StandardScaler_LR-PCA                  0.853    0.005   0.858
# 12   weatherAUS  MinMaxScaler_LR-PCA                    0.825    0.006   0.823
# 13   weatherAUS  MaxAbsScaler_LR-PCA                    0.821    0.007   0.819
# 14   weatherAUS  RobustScaler_LR-PCA                    1.000    0.000   1.000
# 15   weatherAUS  QuantileTransformer-Normal_LR-PCA      0.954    0.003   0.956
# 16   weatherAUS  QuantileTransformer-Uniform_LR-PCA     0.885    0.006   0.889
# 17   weatherAUS  PowerTransformer-Yeo-Johnson_LR-PCA    0.872    0.005   0.874
# 18   weatherAUS  Normalizer_LR-PCA                      0.821    0.003   0.827
# 20   weatherAUS  _LDA                                   0.880    0.003   0.883
# 21   weatherAUS  StandardScaler_LDA                     0.880    0.003   0.883
# 22   weatherAUS  MinMaxScaler_LDA                       0.880    0.003   0.883
# 23   weatherAUS  MaxAbsScaler_LDA                       0.880    0.003   0.883
# 24   weatherAUS  RobustScaler_LDA                       0.880    0.003   0.883
# 25   weatherAUS  QuantileTransformer-Normal_LDA         0.884    0.004   0.883
# 26   weatherAUS  QuantileTransformer-Uniform_LDA        0.884    0.004   0.883
# 27   weatherAUS  PowerTransformer-Yeo-Johnson_LDA       0.961    0.003   0.963
# 28   weatherAUS  Normalizer_LDA                         0.884    0.003   0.888
# 30   weatherAUS  _LDA-PCA                               0.850    0.005   0.852
# 31   weatherAUS  StandardScaler_LDA-PCA                 0.853    0.004   0.859
# 32   weatherAUS  MinMaxScaler_LDA-PCA                   0.824    0.007   0.821
# 33   weatherAUS  MaxAbsScaler_LDA-PCA                   0.819    0.007   0.818
# 34   weatherAUS  RobustScaler_LDA-PCA                   0.860    0.003   0.865
# 35   weatherAUS  QuantileTransformer-Normal_LDA-PCA     0.872    0.004   0.871
# 36   weatherAUS  QuantileTransformer-Uniform_LDA-PCA    0.885    0.006   0.887
# 37   weatherAUS  PowerTransformer-Yeo-Johnson_LDA-PCA   0.869    0.005   0.870
# 38   weatherAUS  Normalizer_LDA-PCA                     0.848    0.004   0.850
# 40   weatherAUS  _KNN                                   0.890    0.004   0.893
# 41   weatherAUS  StandardScaler_KNN                     0.890    0.004   0.894
# 42   weatherAUS  MinMaxScaler_KNN                       0.845    0.004   0.847
# 43   weatherAUS  MaxAbsScaler_KNN                       0.840    0.004   0.847
# 44   weatherAUS  RobustScaler_KNN                       0.991    0.002   0.991
# 45   weatherAUS  QuantileTransformer-Normal_KNN         0.917    0.003   0.924
# 46   weatherAUS  QuantileTransformer-Uniform_KNN        0.919    0.003   0.924
# 47   weatherAUS  PowerTransformer-Yeo-Johnson_KNN       0.974    0.002   0.975
# 48   weatherAUS  Normalizer_KNN                         0.893    0.004   0.896
# 50   weatherAUS  _KNN-PCA                               0.836    0.006   0.836
# 51   weatherAUS  StandardScaler_KNN-PCA                 0.839    0.007   0.843
# 52   weatherAUS  MinMaxScaler_KNN-PCA                   0.814    0.005   0.810
# 53   weatherAUS  MaxAbsScaler_KNN-PCA                   0.808    0.006   0.804
# 54   weatherAUS  RobustScaler_KNN-PCA                   0.995    0.001   0.996
# 55   weatherAUS  QuantileTransformer-Normal_KNN-PCA     0.954    0.003   0.956
# 56   weatherAUS  QuantileTransformer-Uniform_KNN-PCA    0.878    0.007   0.877
# 57   weatherAUS  PowerTransformer-Yeo-Johnson_KNN-PCA   0.858    0.006   0.861
# 58   weatherAUS  Normalizer_KNN-PCA                     0.834    0.006   0.840
# 60   weatherAUS  _CART                                  1.000    0.000   1.000
# 61   weatherAUS  StandardScaler_CART                    1.000    0.000   1.000
# 62   weatherAUS  MinMaxScaler_CART                      1.000    0.000   1.000
# 63   weatherAUS  MaxAbsScaler_CART                      1.000    0.000   1.000
# 64   weatherAUS  RobustScaler_CART                      1.000    0.000   1.000
# 65   weatherAUS  QuantileTransformer-Normal_CART        1.000    0.000   1.000
# 66   weatherAUS  QuantileTransformer-Uniform_CART       1.000    0.000   1.000
# 67   weatherAUS  PowerTransformer-Yeo-Johnson_CART      1.000    0.000   1.000
# 68   weatherAUS  Normalizer_CART                        1.000    0.000   1.000
# 70   weatherAUS  _CART-PCA                              0.780    0.005   0.787
# 71   weatherAUS  StandardScaler_CART-PCA                0.792    0.007   0.796
# 72   weatherAUS  MinMaxScaler_CART-PCA                  0.759    0.006   0.758
# 73   weatherAUS  MaxAbsScaler_CART-PCA                  0.753    0.008   0.752
# 74   weatherAUS  RobustScaler_CART-PCA                  0.997    0.001   0.997
# 75   weatherAUS  QuantileTransformer-Normal_CART-PCA    0.943    0.003   0.942
# 76   weatherAUS  QuantileTransformer-Uniform_CART-PCA   0.844    0.007   0.844
# 77   weatherAUS  PowerTransformer-Yeo-Johnson_CART-PCA  0.818    0.006   0.823
# 78   weatherAUS  Normalizer_CART-PCA                    0.780    0.004   0.784
# 80   weatherAUS  _NB                                    0.950    0.003   0.951
# 81   weatherAUS  StandardScaler_NB                      0.950    0.003   0.951
# 82   weatherAUS  MinMaxScaler_NB                        0.950    0.003   0.951
# 83   weatherAUS  MaxAbsScaler_NB                        0.950    0.003   0.951
# 84   weatherAUS  RobustScaler_NB                        0.950    0.003   0.951
# 85   weatherAUS  QuantileTransformer-Normal_NB          0.891    0.004   0.888
# 86   weatherAUS  QuantileTransformer-Uniform_NB         0.916    0.004   0.914
# 87   weatherAUS  PowerTransformer-Yeo-Johnson_NB        0.978    0.002   0.978
# 88   weatherAUS  Normalizer_NB                          0.942    0.004   0.942
# 90   weatherAUS  _NB-PCA                                0.844    0.005   0.847
# 91   weatherAUS  StandardScaler_NB-PCA                  0.834    0.004   0.842
# 92   weatherAUS  MinMaxScaler_NB-PCA                    0.823    0.006   0.819
# 93   weatherAUS  MaxAbsScaler_NB-PCA                    0.814    0.007   0.812
# 94   weatherAUS  RobustScaler_NB-PCA                    0.871    0.004   0.881
# 95   weatherAUS  QuantileTransformer-Normal_NB-PCA      0.893    0.004   0.893
# 96   weatherAUS  QuantileTransformer-Uniform_NB-PCA     0.880    0.004   0.883
# 97   weatherAUS  PowerTransformer-Yeo-Johnson_NB-PCA    0.864    0.003   0.868
# 98   weatherAUS  Normalizer_NB-PCA                      0.844    0.005   0.847
# 100  weatherAUS  _SVM                                   0.780    0.004   0.780
# 101  weatherAUS  StandardScaler_SVM                     0.978    0.002   0.979
# 102  weatherAUS  MinMaxScaler_SVM                       0.869    0.003   0.874
# 103  weatherAUS  MaxAbsScaler_SVM                       0.868    0.005   0.870
# 104  weatherAUS  RobustScaler_SVM                       0.998    0.001   0.998
# 105  weatherAUS  QuantileTransformer-Normal_SVM         0.985    0.002   0.987
# 106  weatherAUS  QuantileTransformer-Uniform_SVM        0.994    0.001   0.996
# 107  weatherAUS  PowerTransformer-Yeo-Johnson_SVM       0.997    0.001   0.997
# 108  weatherAUS  Normalizer_SVM                         0.780    0.004   0.780
# 110  weatherAUS  _SVM-PCA                               0.780    0.005   0.782
# 111  weatherAUS  StandardScaler_SVM-PCA                 0.854    0.005   0.860
# 112  weatherAUS  MinMaxScaler_SVM-PCA                   0.824    0.005   0.826
# 113  weatherAUS  MaxAbsScaler_SVM-PCA                   0.820    0.006   0.819
# 114  weatherAUS  RobustScaler_SVM-PCA                   0.998    0.001   0.998
# 115  weatherAUS  QuantileTransformer-Normal_SVM-PCA     0.965    0.002   0.968
# 116  weatherAUS  QuantileTransformer-Uniform_SVM-PCA    0.886    0.006   0.890
# 117  weatherAUS  PowerTransformer-Yeo-Johnson_SVM-PCA   0.873    0.006   0.876
# 118  weatherAUS  Normalizer_SVM-PCA                     0.781    0.004   0.782
# 120  weatherAUS  _RF                                    0.970    0.003   0.971
# 121  weatherAUS  StandardScaler_RF                      0.970    0.003   0.971
# 122  weatherAUS  MinMaxScaler_RF                        0.970    0.003   0.971
# 123  weatherAUS  MaxAbsScaler_RF                        0.970    0.003   0.971
# 124  weatherAUS  RobustScaler_RF                        0.970    0.003   0.971
# 125  weatherAUS  QuantileTransformer-Normal_RF          0.970    0.003   0.972
# 126  weatherAUS  QuantileTransformer-Uniform_RF         0.970    0.003   0.972
# 127  weatherAUS  PowerTransformer-Yeo-Johnson_RF        0.970    0.003   0.971
# 128  weatherAUS  Normalizer_RF                          0.948    0.005   0.951
# 130  weatherAUS  _RF-PCA                                0.831    0.004   0.836
# 131  weatherAUS  StandardScaler_RF-PCA                  0.846    0.004   0.854
# 132  weatherAUS  MinMaxScaler_RF-PCA                    0.801    0.005   0.803
# 133  weatherAUS  MaxAbsScaler_RF-PCA                    0.809    0.005   0.810
# 134  weatherAUS  RobustScaler_RF-PCA                    0.947    0.005   0.955
# 135  weatherAUS  QuantileTransformer-Normal_RF-PCA      0.907    0.004   0.904
# 136  weatherAUS  QuantileTransformer-Uniform_RF-PCA     0.859    0.004   0.866
# 137  weatherAUS  PowerTransformer-Yeo-Johnson_RF-PCA    0.861    0.005   0.868
# 138  weatherAUS  Normalizer_RF-PCA                      0.839    0.004   0.840
# 140  weatherAUS  _MLP                                   0.992    0.010   0.999
# 141  weatherAUS  StandardScaler_MLP                     1.000    0.000   1.000
# 142  weatherAUS  MinMaxScaler_MLP                       0.998    0.002   1.000
# 143  weatherAUS  MaxAbsScaler_MLP                       0.998    0.003   1.000
# 144  weatherAUS  RobustScaler_MLP                       1.000    0.000   1.000
# 145  weatherAUS  QuantileTransformer-Normal_MLP         0.999    0.000   0.999
# 146  weatherAUS  QuantileTransformer-Uniform_MLP        0.999    0.002   1.000
# 147  weatherAUS  PowerTransformer-Yeo-Johnson_MLP       1.000    0.000   1.000
# 148  weatherAUS  Normalizer_MLP                         0.999    0.002   0.998
# 150  weatherAUS  _MLP-PCA                               0.851    0.006   0.854
# 151  weatherAUS  StandardScaler_MLP-PCA                 0.855    0.005   0.859
# 152  weatherAUS  MinMaxScaler_MLP-PCA                   0.830    0.004   0.832
# 153  weatherAUS  MaxAbsScaler_MLP-PCA                   0.827    0.005   0.827
# 154  weatherAUS  RobustScaler_MLP-PCA                   1.000    0.000   1.000
# 155  weatherAUS  QuantileTransformer-Normal_MLP-PCA     0.965    0.002   0.968
# 156  weatherAUS  QuantileTransformer-Uniform_MLP-PCA    0.888    0.005   0.892
# 157  weatherAUS  PowerTransformer-Yeo-Johnson_MLP-PCA   0.873    0.006   0.875
# 158  weatherAUS  Normalizer_MLP-PCA                     0.849    0.005   0.851

# %% [markdown]
# <a id="Out-of-the-box_classifier"></a>
# # 1. Out-of-the-box classifiers

# %%
import operator
results_df.loc[operator.and_(results_df["Classifier_Name"].str.startswith("_"), ~results_df["Classifier_Name"].str.endswith("PCA"))].dropna()
# Out:
#         Dataset Classifier_Name  CV_mean  CV_std  Test_score
# 0    weatherAUS  _LR             1.000    0.000   1.000
# 20   weatherAUS  _LDA            0.880    0.003   0.883
# 40   weatherAUS  _KNN            0.890    0.004   0.893
# 60   weatherAUS  _CART           1.000    0.000   1.000
# 80   weatherAUS  _NB             0.950    0.003   0.951
# 100  weatherAUS  _SVM            0.780    0.004   0.780
# 120  weatherAUS  _RF             0.970    0.003   0.971
# 140  weatherAUS  _MLP            0.992    0.010   0.999

# %% [markdown]
# Nice results.
# We can see that at the moment, MLF is on the lead.
#
# Now, let's see how different scaling methods change the scores for each classifier

# %% [markdown]
# <a id="Classifiers_Scaling"></a>
# # 2. Classifiers+Scaling

# %%
import operator
import numpy as np


temp = results_df.loc[~results_df["Classifier_Name"].str.endswith("PCA")].dropna()
temp["model"] = results_df["Classifier_Name"].apply(lambda sen: sen.split("_")[1])
temp["scaler"] = results_df["Classifier_Name"].apply(lambda sen: sen.split("_")[0])

def df_style(val):
    return 'font-weight: 800'
    

pivot_t = pd.pivot_table(temp, values='CV_mean', index=["scaler"], columns=['model'], aggfunc=np.sum)
pivot_t_bold = pivot_t.style.applymap(df_style,
                      subset=pd.IndexSlice[pivot_t["CART"].idxmax(),"CART"])
for col in list(pivot_t):
    pivot_t_bold = pivot_t_bold.applymap(df_style,
                      subset=pd.IndexSlice[pivot_t[col].idxmax(),col])
pivot_t_bold
# Out:
# <style  type="text/css" >
#     #T_62de762e_5487_11e9_a4c6_d0c5d31508a0row0_col0 {
#             font-weight:  800;
#             font-weight:  800;
#         }    #T_62de762e_5487_11e9_a4c6_d0c5d31508a0row0_col3 {
#             font-weight:  800;
#         }    #T_62de762e_5487_11e9_a4c6_d0c5d31508a0row0_col6 {
#             font-weight:  800;
#         }    #T_62de762e_5487_11e9_a4c6_d0c5d31508a0row4_col2 {
#             font-weight:  800;
#         }    #T_62de762e_5487_11e9_a4c6_d0c5d31508a0row4_col4 {
#             font-weight:  800;
#         }    #T_62de762e_5487_11e9_a4c6_d0c5d31508a0row4_col5 {
#             font-weight:  800;
#         }    #T_62de762e_5487_11e9_a4c6_d0c5d31508a0row7_col1 {
#             font-weight:  800;
#         }    #T_62de762e_5487_11e9_a4c6_d0c5d31508a0row7_col7 {
#             font-weight:  800;
#         }</style>
# <table id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0" >
# <thead>    <tr>
#         <th class="index_name level0" >model</th>
#         <th class="col_heading level0 col0" >CART</th>
#         <th class="col_heading level0 col1" >KNN</th>
#         <th class="col_heading level0 col2" >LDA</th>
#         <th class="col_heading level0 col3" >LR</th>
#         <th class="col_heading level0 col4" >MLP</th>
#         <th class="col_heading level0 col5" >NB</th>
#         <th class="col_heading level0 col6" >RF</th>
#         <th class="col_heading level0 col7" >SVM</th>
#     </tr>    <tr>
#         <th class="index_name level0" >scaler</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0level0_row0" class="row_heading level0 row0" ></th>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row0_col0" class="data row0 col0" >1</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row0_col1" class="data row0 col1" >0.89</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row0_col2" class="data row0 col2" >0.88</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row0_col3" class="data row0 col3" >1</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row0_col4" class="data row0 col4" >0.992</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row0_col5" class="data row0 col5" >0.95</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row0_col6" class="data row0 col6" >0.97</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row0_col7" class="data row0 col7" >0.78</td>
#     </tr>    <tr>
#         <th id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0level0_row1" class="row_heading level0 row1" >MaxAbsScaler</th>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row1_col0" class="data row1 col0" >1</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row1_col1" class="data row1 col1" >0.84</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row1_col2" class="data row1 col2" >0.88</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row1_col3" class="data row1 col3" >0.887</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row1_col4" class="data row1 col4" >0.998</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row1_col5" class="data row1 col5" >0.95</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row1_col6" class="data row1 col6" >0.97</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row1_col7" class="data row1 col7" >0.868</td>
#     </tr>    <tr>
#         <th id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0level0_row2" class="row_heading level0 row2" >MinMaxScaler</th>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row2_col0" class="data row2 col0" >1</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row2_col1" class="data row2 col1" >0.845</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row2_col2" class="data row2 col2" >0.88</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row2_col3" class="data row2 col3" >0.887</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row2_col4" class="data row2 col4" >0.998</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row2_col5" class="data row2 col5" >0.95</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row2_col6" class="data row2 col6" >0.97</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row2_col7" class="data row2 col7" >0.869</td>
#     </tr>    <tr>
#         <th id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0level0_row3" class="row_heading level0 row3" >Normalizer</th>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row3_col0" class="data row3 col0" >1</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row3_col1" class="data row3 col1" >0.893</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row3_col2" class="data row3 col2" >0.884</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row3_col3" class="data row3 col3" >0.827</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row3_col4" class="data row3 col4" >0.999</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row3_col5" class="data row3 col5" >0.942</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row3_col6" class="data row3 col6" >0.948</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row3_col7" class="data row3 col7" >0.78</td>
#     </tr>    <tr>
#         <th id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0level0_row4" class="row_heading level0 row4" >PowerTransformer-Yeo-Johnson</th>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row4_col0" class="data row4 col0" >1</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row4_col1" class="data row4 col1" >0.974</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row4_col2" class="data row4 col2" >0.961</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row4_col3" class="data row4 col3" >1</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row4_col4" class="data row4 col4" >1</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row4_col5" class="data row4 col5" >0.978</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row4_col6" class="data row4 col6" >0.97</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row4_col7" class="data row4 col7" >0.997</td>
#     </tr>    <tr>
#         <th id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0level0_row5" class="row_heading level0 row5" >QuantileTransformer-Normal</th>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row5_col0" class="data row5 col0" >1</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row5_col1" class="data row5 col1" >0.917</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row5_col2" class="data row5 col2" >0.884</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row5_col3" class="data row5 col3" >1</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row5_col4" class="data row5 col4" >0.999</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row5_col5" class="data row5 col5" >0.891</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row5_col6" class="data row5 col6" >0.97</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row5_col7" class="data row5 col7" >0.985</td>
#     </tr>    <tr>
#         <th id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0level0_row6" class="row_heading level0 row6" >QuantileTransformer-Uniform</th>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row6_col0" class="data row6 col0" >1</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row6_col1" class="data row6 col1" >0.919</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row6_col2" class="data row6 col2" >0.884</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row6_col3" class="data row6 col3" >0.994</td>
#         <td id="T_62de762e_5487_11e9_a4c6_d0c5d31508a0row6_col

# %%
# Print table for the Medium article

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 100000)
pd.options.display.max_rows
pd.set_option('display.max_colwidth', -1)

dict2 = {'StandardScaler': "StandardScaler",
'MinMaxScaler':"MinMaxScaler",
'MaxAbsScaler':"MaxAbsScaler",
'RobustScaler':"RobustScaler",
'QuantileTransformer-Normal':"QuantileTransformer(output_distribution='normal')",
'QuantileTransformer-Uniform':"QuantileTransformer(output_distribution='uniform')",
'PowerTransformer-Yeo-Johnson':"PowerTransformer(method='yeo-johnson')",
'Normalizer':"Normalizer"}

scalers_df = pd.DataFrame(list(dict2.items()), columns=["Name","Sklearn_Class"])
s = scalers_df.style.set_properties(subset=["Name", "Sklearn_Class"], **{'text-align': 'left'})
s.set_table_styles([ dict(selector='th', props=[('text-align', 'left')] ) ])
# Out:
# <style  type="text/css" >
#     #T_6361a970_5487_11e9_972a_d0c5d31508a0 th {
#           text-align: left;
#     }    #T_6361a970_5487_11e9_972a_d0c5d31508a0row0_col0 {
#             text-align:  left;
#         }    #T_6361a970_5487_11e9_972a_d0c5d31508a0row0_col1 {
#             text-align:  left;
#         }    #T_6361a970_5487_11e9_972a_d0c5d31508a0row1_col0 {
#             text-align:  left;
#         }    #T_6361a970_5487_11e9_972a_d0c5d31508a0row1_col1 {
#             text-align:  left;
#         }    #T_6361a970_5487_11e9_972a_d0c5d31508a0row2_col0 {
#             text-align:  left;
#         }    #T_6361a970_5487_11e9_972a_d0c5d31508a0row2_col1 {
#             text-align:  left;
#         }    #T_6361a970_5487_11e9_972a_d0c5d31508a0row3_col0 {
#             text-align:  left;
#         }    #T_6361a970_5487_11e9_972a_d0c5d31508a0row3_col1 {
#             text-align:  left;
#         }    #T_6361a970_5487_11e9_972a_d0c5d31508a0row4_col0 {
#             text-align:  left;
#         }    #T_6361a970_5487_11e9_972a_d0c5d31508a0row4_col1 {
#             text-align:  left;
#         }    #T_6361a970_5487_11e9_972a_d0c5d31508a0row5_col0 {
#             text-align:  left;
#         }    #T_6361a970_5487_11e9_972a_d0c5d31508a0row5_col1 {
#             text-align:  left;
#         }    #T_6361a970_5487_11e9_972a_d0c5d31508a0row6_col0 {
#             text-align:  left;
#         }    #T_6361a970_5487_11e9_972a_d0c5d31508a0row6_col1 {
#             text-align:  left;
#         }    #T_6361a970_5487_11e9_972a_d0c5d31508a0row7_col0 {
#             text-align:  left;
#         }    #T_6361a970_5487_11e9_972a_d0c5d31508a0row7_col1 {
#             text-align:  left;
#         }</style>
# <table id="T_6361a970_5487_11e9_972a_d0c5d31508a0" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Name</th>
#         <th class="col_heading level0 col1" >Sklearn_Class</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6361a970_5487_11e9_972a_d0c5d31508a0level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_6361a970_5487_11e9_972a_d0c5d31508a0row0_col0" class="data row0 col0" >StandardScaler</td>
#         <td id="T_6361a970_5487_11e9_972a_d0c5d31508a0row0_col1" class="data row0 col1" >StandardScaler</td>
#     </tr>    <tr>
#         <th id="T_6361a970_5487_11e9_972a_d0c5d31508a0level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_6361a970_5487_11e9_972a_d0c5d31508a0row1_col0" class="data row1 col0" >MinMaxScaler</td>
#         <td id="T_6361a970_5487_11e9_972a_d0c5d31508a0row1_col1" class="data row1 col1" >MinMaxScaler</td>
#     </tr>    <tr>
#         <th id="T_6361a970_5487_11e9_972a_d0c5d31508a0level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_6361a970_5487_11e9_972a_d0c5d31508a0row2_col0" class="data row2 col0" >MaxAbsScaler</td>
#         <td id="T_6361a970_5487_11e9_972a_d0c5d31508a0row2_col1" class="data row2 col1" >MaxAbsScaler</td>
#     </tr>    <tr>
#         <th id="T_6361a970_5487_11e9_972a_d0c5d31508a0level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_6361a970_5487_11e9_972a_d0c5d31508a0row3_col0" class="data row3 col0" >RobustScaler</td>
#         <td id="T_6361a970_5487_11e9_972a_d0c5d31508a0row3_col1" class="data row3 col1" >RobustScaler</td>
#     </tr>    <tr>
#         <th id="T_6361a970_5487_11e9_972a_d0c5d31508a0level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_6361a970_5487_11e9_972a_d0c5d31508a0row4_col0" class="data row4 col0" >QuantileTransformer-Normal</td>
#         <td id="T_6361a970_5487_11e9_972a_d0c5d31508a0row4_col1" class="data row4 col1" >QuantileTransformer(output_distribution='normal')</td>
#     </tr>    <tr>
#         <th id="T_6361a970_5487_11e9_972a_d0c5d31508a0level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_6361a970_5487_11e9_972a_d0c5d31508a0row5_col0" class="data row5 col0" >QuantileTransformer-Uniform</td>
#         <td id="T_6361a970_5487_11e9_972a_d0c5d31508a0row5_col1" class="data row5 col1" >QuantileTransformer(output_distribution='uniform')</td>
#     </tr>    <tr>
#         <th id="T_6361a970_5487_11e9_972a_d0c5d31508a0level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_6361a970_5487_11e9_972a_d0c5d31508a0row6_col0" class="data row6 col0" >PowerTransformer-Yeo-Johnson</td>
#         <td id="T_6361a970_5487_11e9_972a_d0c5d31508a0row6_col1" class="data row6 col1" >PowerTransformer(method='yeo-johnson')</td>
#     </tr>    <tr>
#         <th id="T_6361a970_5487_11e9_972a_d0c5d31508a0level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_6361a970_5487_11e9_972a_d0c5d31508a0row7_col0" class="data row7 col0" >Normalizer</td>
#         <td id="T_6361a970_5487_11e9_972a_d0c5d31508a0row7_col1" class="data row7 col1" >Normalizer</td>
#     </tr></tbody>
# </table>

# %%
# Print table for the Medium article
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 100000)
pd.options.display.max_rows
pd.set_option('display.max_colwidth', -1)

dict2 = {'LR': "LogisticRegression",
'LDA':"LinearDiscriminantAnalysis",
'KNN':"KNeighborsClassifier",
'CART':"DecisionTreeClassifier",
'NB':"GaussianNB",
'SVM':"SVC",
'RF':"RandomForestClassifier",
'MLP':"MLPClassifier"}

scalers_df = pd.DataFrame(list(dict2.items()), columns=["Name","Sklearn_Class"])
s = scalers_df.style.set_properties(subset=["Name", "Sklearn_Class"], **{'text-align': 'left'})
s.set_table_styles([ dict(selector='th', props=[('text-align', 'left')] ) ])
# Out:
# <style  type="text/css" >
#     #T_63e1a868_5487_11e9_bc1f_d0c5d31508a0 th {
#           text-align: left;
#     }    #T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row0_col0 {
#             text-align:  left;
#         }    #T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row0_col1 {
#             text-align:  left;
#         }    #T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row1_col0 {
#             text-align:  left;
#         }    #T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row1_col1 {
#             text-align:  left;
#         }    #T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row2_col0 {
#             text-align:  left;
#         }    #T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row2_col1 {
#             text-align:  left;
#         }    #T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row3_col0 {
#             text-align:  left;
#         }    #T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row3_col1 {
#             text-align:  left;
#         }    #T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row4_col0 {
#             text-align:  left;
#         }    #T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row4_col1 {
#             text-align:  left;
#         }    #T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row5_col0 {
#             text-align:  left;
#         }    #T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row5_col1 {
#             text-align:  left;
#         }    #T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row6_col0 {
#             text-align:  left;
#         }    #T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row6_col1 {
#             text-align:  left;
#         }    #T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row7_col0 {
#             text-align:  left;
#         }    #T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row7_col1 {
#             text-align:  left;
#         }</style>
# <table id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Name</th>
#         <th class="col_heading level0 col1" >Sklearn_Class</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row0_col0" class="data row0 col0" >LR</td>
#         <td id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row0_col1" class="data row0 col1" >LogisticRegression</td>
#     </tr>    <tr>
#         <th id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row1_col0" class="data row1 col0" >LDA</td>
#         <td id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row1_col1" class="data row1 col1" >LinearDiscriminantAnalysis</td>
#     </tr>    <tr>
#         <th id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row2_col0" class="data row2 col0" >KNN</td>
#         <td id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row2_col1" class="data row2 col1" >KNeighborsClassifier</td>
#     </tr>    <tr>
#         <th id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row3_col0" class="data row3 col0" >CART</td>
#         <td id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row3_col1" class="data row3 col1" >DecisionTreeClassifier</td>
#     </tr>    <tr>
#         <th id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row4_col0" class="data row4 col0" >NB</td>
#         <td id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row4_col1" class="data row4 col1" >GaussianNB</td>
#     </tr>    <tr>
#         <th id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row5_col0" class="data row5 col0" >SVM</td>
#         <td id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row5_col1" class="data row5 col1" >SVC</td>
#     </tr>    <tr>
#         <th id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row6_col0" class="data row6 col0" >RF</td>
#         <td id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row6_col1" class="data row6 col1" >RandomForestClassifier</td>
#     </tr>    <tr>
#         <th id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row7_col0" class="data row7 col0" >MLP</td>
#         <td id="T_63e1a868_5487_11e9_bc1f_d0c5d31508a0row7_col1" class="data row7 col1" >MLPClassifier</td>
#     </tr></tbody>
# </table>

# %%
import operator

cols_max_vals = {}
cols_max_row_names = {}
for col in list(pivot_t):
    row_name = pivot_t[col].idxmax()
    cell_val = pivot_t[col].max()
    cols_max_vals[col] = cell_val
    cols_max_row_names[col] = row_name
    
sorted_cols_max_vals = sorted(cols_max_vals.items(), key=lambda kv: kv[1], reverse=True)

print("Best classifiers sorted:\n")
counter = 1
for model, score in sorted_cols_max_vals:
    print(str(counter) + ". " + model + " + " +cols_max_row_names[model] + " : " +str(score))
    counter +=1
# Out:
# Best classifiers sorted:
#
# 1. CART +  : 1.0
# 2. LR +  : 1.0
# 3. MLP + PowerTransformer-Yeo-Johnson : 1.0
# 4. SVM + RobustScaler : 0.998
# 5. KNN + RobustScaler : 0.991
# 6. NB + PowerTransformer-Yeo-Johnson : 0.978
# 7. RF +  : 0.97
# 8. LDA + PowerTransformer-Yeo-Johnson : 0.961

# %% [markdown]
# ## Let's analyze the results

# %% [markdown]
# 1. <b>There is no single scaling method to rule them all.</b>
#
#
# 2. We can see that scaling improved the results. SVM, MLP, KNN, and NB got a significant boost from different scaling methods.
#
#
# 3. Notice that NB, RF, LDA, CART are <b>unaffected</b> by some of the scaling methods. This is, of course, related to how each of the classifiers works. Trees are not affected by scaling because the splitting criterion first orders the values of each feature and then calculate the gini\entropy of the split. Some scaling methods don't affect this order so no change to the accuracy score. <br>
#     NB is not affected because the model's priors affected by the count in each class and not by the actual value. LDA fits a Gaussian density to each class, so the scaling doesn't matter either.
#
#
# 4. Some of the scaling methods, like QuantileTransformer-Uniform, doesn't preserve the exact order of the values in each feature, hence the change in score even in the above classifiers that were agnostic to other scaling methods.

# %% [markdown]
# <a id="Classifiers_Scaling_pca"></a>
# # 3. Classifier+Scaling+PCA
#
# We know that some well-known ML methods like PCA can benefit from scaling (<a href="https://sebastianraschka.com/Articles/2014_about_feature_scaling.html">blog</a>).
# Let's try adding PCA(n_components=4) to the pipeline and analyze the results.

# %%
import operator
temp = results_df.copy()
temp["model"] = results_df["Classifier_Name"].apply(lambda sen: sen.split("_")[1])
temp["scaler"] = results_df["Classifier_Name"].apply(lambda sen: sen.split("_")[0])

def df_style(val):
    return 'font-weight: 800'
    

pivot_t = pd.pivot_table(temp, values='CV_mean', index=["scaler"], columns=['model'], aggfunc=np.sum)
pivot_t_bold = pivot_t.style.applymap(df_style,
                      subset=pd.IndexSlice[pivot_t["CART"].idxmax(),"CART"])
for col in list(pivot_t):
    pivot_t_bold = pivot_t_bold.applymap(df_style,
                      subset=pd.IndexSlice[pivot_t[col].idxmax(),col])
pivot_t_bold
# Out:
# <style  type="text/css" >
#     #T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col0 {
#             font-weight:  800;
#             font-weight:  800;
#         }    #T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col6 {
#             font-weight:  800;
#         }    #T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col12 {
#             font-weight:  800;
#         }    #T_66955ac2_5487_11e9_8d40_d0c5d31508a0row4_col4 {
#             font-weight:  800;
#         }    #T_66955ac2_5487_11e9_8d40_d0c5d31508a0row4_col8 {
#             font-weight:  800;
#         }    #T_66955ac2_5487_11e9_8d40_d0c5d31508a0row4_col10 {
#             font-weight:  800;
#         }    #T_66955ac2_5487_11e9_8d40_d0c5d31508a0row5_col11 {
#             font-weight:  800;
#         }    #T_66955ac2_5487_11e9_8d40_d0c5d31508a0row6_col5 {
#             font-weight:  800;
#         }    #T_66955ac2_5487_11e9_8d40_d0c5d31508a0row7_col1 {
#             font-weight:  800;
#         }    #T_66955ac2_5487_11e9_8d40_d0c5d31508a0row7_col2 {
#             font-weight:  800;
#         }    #T_66955ac2_5487_11e9_8d40_d0c5d31508a0row7_col3 {
#             font-weight:  800;
#         }    #T_66955ac2_5487_11e9_8d40_d0c5d31508a0row7_col7 {
#             font-weight:  800;
#         }    #T_66955ac2_5487_11e9_8d40_d0c5d31508a0row7_col9 {
#             font-weight:  800;
#         }    #T_66955ac2_5487_11e9_8d40_d0c5d31508a0row7_col13 {
#             font-weight:  800;
#         }    #T_66955ac2_5487_11e9_8d40_d0c5d31508a0row7_col14 {
#             font-weight:  800;
#         }    #T_66955ac2_5487_11e9_8d40_d0c5d31508a0row7_col15 {
#             font-weight:  800;
#         }</style>
# <table id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0" >
# <thead>    <tr>
#         <th class="index_name level0" >model</th>
#         <th class="col_heading level0 col0" >CART</th>
#         <th class="col_heading level0 col1" >CART-PCA</th>
#         <th class="col_heading level0 col2" >KNN</th>
#         <th class="col_heading level0 col3" >KNN-PCA</th>
#         <th class="col_heading level0 col4" >LDA</th>
#         <th class="col_heading level0 col5" >LDA-PCA</th>
#         <th class="col_heading level0 col6" >LR</th>
#         <th class="col_heading level0 col7" >LR-PCA</th>
#         <th class="col_heading level0 col8" >MLP</th>
#         <th class="col_heading level0 col9" >MLP-PCA</th>
#         <th class="col_heading level0 col10" >NB</th>
#         <th class="col_heading level0 col11" >NB-PCA</th>
#         <th class="col_heading level0 col12" >RF</th>
#         <th class="col_heading level0 col13" >RF-PCA</th>
#         <th class="col_heading level0 col14" >SVM</th>
#         <th class="col_heading level0 col15" >SVM-PCA</th>
#     </tr>    <tr>
#         <th class="index_name level0" >scaler</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0level0_row0" class="row_heading level0 row0" ></th>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col0" class="data row0 col0" >1</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col1" class="data row0 col1" >0.78</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col2" class="data row0 col2" >0.89</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col3" class="data row0 col3" >0.836</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col4" class="data row0 col4" >0.88</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col5" class="data row0 col5" >0.85</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col6" class="data row0 col6" >1</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col7" class="data row0 col7" >0.85</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col8" class="data row0 col8" >0.992</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col9" class="data row0 col9" >0.851</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col10" class="data row0 col10" >0.95</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col11" class="data row0 col11" >0.844</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col12" class="data row0 col12" >0.97</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col13" class="data row0 col13" >0.831</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col14" class="data row0 col14" >0.78</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row0_col15" class="data row0 col15" >0.78</td>
#     </tr>    <tr>
#         <th id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0level0_row1" class="row_heading level0 row1" >MaxAbsScaler</th>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row1_col0" class="data row1 col0" >1</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row1_col1" class="data row1 col1" >0.753</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row1_col2" class="data row1 col2" >0.84</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row1_col3" class="data row1 col3" >0.808</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row1_col4" class="data row1 col4" >0.88</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row1_col5" class="data row1 col5" >0.819</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row1_col6" class="data row1 col6" >0.887</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row1_col7" class="data row1 col7" >0.821</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row1_col8" class="data row1 col8" >0.998</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row1_col9" class="data row1 col9" >0.827</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row1_col10" class="data row1 col10" >0.95</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row1_col11" class="data row1 col11" >0.814</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row1_col12" class="data row1 col12" >0.97</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row1_col13" class="data row1 col13" >0.809</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row1_col14" class="data row1 col14" >0.868</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row1_col15" class="data row1 col15" >0.82</td>
#     </tr>    <tr>
#         <th id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0level0_row2" class="row_heading level0 row2" >MinMaxScaler</th>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row2_col0" class="data row2 col0" >1</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row2_col1" class="data row2 col1" >0.759</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row2_col2" class="data row2 col2" >0.845</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row2_col3" class="data row2 col3" >0.814</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row2_col4" class="data row2 col4" >0.88</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row2_col5" class="data row2 col5" >0.824</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row2_col6" class="data row2 col6" >0.887</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row2_col7" class="data row2 col7" >0.825</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row2_col8" class="data row2 col8" >0.998</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row2_col9" class="data row2 col9" >0.83</td>
#         <td id="T_66955ac2_5487_11e9_8d40_d0c5d31508a0row2_col10" class="data row2 col10" >0.95</td>

# %% [markdown]
# ## Let's analyze the results

# %% [markdown]
# 1. We can see that PCA only improve LDA and RF, so PCA is not a magic solution.<br>
#     It's fine. We didn't hypertune the n_components parameter, and even if we did, PCA doesn't guarantee to improve predictions.
#
#
# 2. Most of the time scaling methods improve models with PCA, <b> but </b> no specific scaling method is in charge. <br>
#     Let's look at "QuantileTransformer-Uniform", the method with most of the high scores. <br>
#     In LDA-PCA it improved the results from 0.704 to 0.783 (8% jump in accuracy!), but in RF-PCA it makes things worse, from 0.711 to 0.668 (4.35% drop in accuracy!) <br>
#     On the other hand, using RF-PCA with "QuantileTransformer-Normal", improved the accuracy to 0.766 (5% jump in accuracy!) <br>
# 3. We can see that StandardScaler and MinMaxScaler achieve best scores only on 4 out of 16 cases. So one should think carefully what scaling method to choose, even as a default one.<br>
#
# <b>We can conclude that even though PCA is a known component that benefits from scaling, no single scaling method always improved our results, and some of them even cause harm</b>

# %% [markdown]
# <a id="Classifiers_Scaling_pca_hyper_param"></a>
#
# # Classifiers+Scaling+PCA+Hyperparameter tuning
#
# There were big differences in the accuracy score between different scaling methods for a given classifier. One can assume that when the hyperparameters are tuned, the difference between the scaling techniques will be minor and we can use StandardScaler or MinMaxScaler as used in many classification pipelines tutorials in the web. <br>
# Let's check that!

# %% [markdown]
# TODO

# %%
import operator

import os
import pandas as pd

results_hyper_file = "sonar_results_hypertune.csv"
results_hyper_df = pd.read_csv(os.path.join("..","data","processed",results_hyper_file)).dropna().round(3)


temp = results_hyper_df.copy()
temp["model"] = results_hyper_df["Classifier_Name"].apply(lambda sen: sen.split("_")[1])
temp["scaler"] = results_hyper_df["Classifier_Name"].apply(lambda sen: sen.split("_")[0])

def df_style(val):
    return 'font-weight: 800'
    

pivot_t = pd.pivot_table(temp, values='CV_mean', index=["scaler"], columns=['model'], aggfunc=np.sum)
pivot_t_bold = pivot_t.style.applymap(df_style,
                      subset=pd.IndexSlice[pivot_t["KNN"].idxmax(),"KNN"])
for col in list(pivot_t):
    pivot_t_bold = pivot_t_bold.applymap(df_style,
                      subset=pd.IndexSlice[pivot_t[col].idxmax(),col])
pivot_t_bold
# Out:
# <style  type="text/css" >
#     #T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row0_col0 {
#             font-weight:  800;
#         }    #T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row1_col9 {
#             font-weight:  800;
#         }    #T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row3_col1 {
#             font-weight:  800;
#         }    #T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row3_col8 {
#             font-weight:  800;
#         }    #T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row3_col12 {
#             font-weight:  800;
#         }    #T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row4_col5 {
#             font-weight:  800;
#         }    #T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row4_col10 {
#             font-weight:  800;
#         }    #T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row4_col11 {
#             font-weight:  800;
#         }    #T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row5_col2 {
#             font-weight:  800;
#             font-weight:  800;
#         }    #T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row5_col4 {
#             font-weight:  800;
#         }    #T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row5_col6 {
#             font-weight:  800;
#         }    #T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row5_col7 {
#             font-weight:  800;
#         }    #T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row6_col3 {
#             font-weight:  800;
#         }    #T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row6_col13 {
#             font-weight:  800;
#         }</style>
# <table id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0" >
# <thead>    <tr>
#         <th class="index_name level0" >model</th>
#         <th class="col_heading level0 col0" >CART</th>
#         <th class="col_heading level0 col1" >CART-PCA</th>
#         <th class="col_heading level0 col2" >KNN</th>
#         <th class="col_heading level0 col3" >KNN-PCA</th>
#         <th class="col_heading level0 col4" >LDA</th>
#         <th class="col_heading level0 col5" >LDA-PCA</th>
#         <th class="col_heading level0 col6" >LR</th>
#         <th class="col_heading level0 col7" >LR-PCA</th>
#         <th class="col_heading level0 col8" >MLP</th>
#         <th class="col_heading level0 col9" >MLP-PCA</th>
#         <th class="col_heading level0 col10" >RF</th>
#         <th class="col_heading level0 col11" >RF-PCA</th>
#         <th class="col_heading level0 col12" >SVM</th>
#         <th class="col_heading level0 col13" >SVM-PCA</th>
#     </tr>    <tr>
#         <th class="index_name level0" >scaler</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0level0_row0" class="row_heading level0 row0" ></th>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row0_col0" class="data row0 col0" >0.734</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row0_col1" class="data row0 col1" >0.704</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row0_col2" class="data row0 col2" >0.85</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row0_col3" class="data row0 col3" >0.771</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row0_col4" class="data row0 col4" >0.77</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row0_col5" class="data row0 col5" >0.676</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row0_col6" class="data row0 col6" >0.76</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row0_col7" class="data row0 col7" >0.689</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row0_col8" class="data row0 col8" >0.734</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row0_col9" class="data row0 col9" >0.651</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row0_col10" class="data row0 col10" >0.771</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row0_col11" class="data row0 col11" >0.699</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row0_col12" class="data row0 col12" >0.789</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row0_col13" class="data row0 col13" >0.67</td>
#     </tr>    <tr>
#         <th id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0level0_row1" class="row_heading level0 row1" >MaxAbsScaler</th>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row1_col0" class="data row1 col0" >0.734</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row1_col1" class="data row1 col1" >0.723</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row1_col2" class="data row1 col2" >0.843</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row1_col3" class="data row1 col3" >0.741</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row1_col4" class="data row1 col4" >0.765</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row1_col5" class="data row1 col5" >0.76</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row1_col6" class="data row1 col6" >0.736</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row1_col7" class="data row1 col7" >0.766</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row1_col8" class="data row1 col8" >0.728</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row1_col9" class="data row1 col9" >0.754</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row1_col10" class="data row1 col10" >0.776</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row1_col11" class="data row1 col11" >0.758</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row1_col12" class="data row1 col12" >0.759</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row1_col13" class="data row1 col13" >0.743</td>
#     </tr>    <tr>
#         <th id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0level0_row2" class="row_heading level0 row2" >MinMaxScaler</th>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row2_col0" class="data row2 col0" >0.734</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row2_col1" class="data row2 col1" >0.657</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row2_col2" class="data row2 col2" >0.837</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row2_col3" class="data row2 col3" >0.753</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row2_col4" class="data row2 col4" >0.782</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row2_col5" class="data row2 col5" >0.754</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row2_col6" class="data row2 col6" >0.711</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row2_col7" class="data row2 col7" >0.766</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row2_col8" class="data row2 col8" >0.746</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row2_col9" class="data row2 col9" >0.742</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row2_col10" class="data row2 col10" >0.776</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row2_col11" class="data row2 col11" >0.722</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row2_col12" class="data row2 col12" >0.735</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row2_col13" class="data row2 col13" >0.737</td>
#     </tr>    <tr>
#         <th id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0level0_row3" class="row_heading level0 row3" >PowerTransformer-Yeo-Johnson</th>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row3_col0" class="data row3 col0" >0.65</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row3_col1" class="data row3 col1" >0.74</td>
#         <td id="T_a5904eb0_5461_11e9_96f2_d0c5d31508a0row3_col2" class="data row3 col2" >0.874<
